# %%
import xarray as xr
import rioxarray as rxr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
data_path = 'C:/Users/345578/Documents/GitHub/Transfer_HPC/fates_params_CA_StuntRanch_5.nc'
Fates_xr  = xr.open_dataset(data_path)

# %%
list(Fates_xr.keys())
# Out:
# ['fates_history_ageclass_bin_edges',
#  'fates_history_coageclass_bin_edges',
#  'fates_history_height_bin_edges',
#  'fates_history_sizeclass_bin_edges',
#  'fates_hydr_htftype_node',
#  'fates_prt_organ_id',
#  'fates_pftname',
#  'fates_hydr_organname_node',
#  'fates_litterclass_name',
#  'fates_prt_organ_name',
#  'fates_alloc_storage_cushion',
#  'fates_allom_agb1',
#  'fates_allom_agb2',
#  'fates_allom_agb3',
#  'fates_allom_agb4',
#  'fates_allom_agb_frac',
#  'fates_allom_amode',
#  'fates_allom_blca_expnt_diff',
#  'fates_allom_cmode',
#  'fates_allom_d2bl1',
#  'fates_allom_d2bl2',
#  'fates_allom_d2bl3',
#  'fates_allom_d2ca_coefficient_max',
#  'fates_allom_d2ca_coefficient_min',
#  'fates_allom_d2h1',
#  'fates_allom_d2h2',
#  'fates_allom_d2h3',
#  'fates_allom_dbh_maxheight',
#  'fates_allom_fmode',
#  'fates_allom_frbstor_repro',
#  'fates_allom_hmode',
#  'fates_allom_l2fr',
#  'fates_allom_la_per_sa_int',
#  'fates_allom_la_per_sa_slp',
#  'fates_allom_lmode',
#  'fates_allom_sai_scaler',
#  'fates_allom_smode',
#  'fates_allom_stmode',
#  'fates_allom_zroot_k',
#  'fates_allom_zroot_max_dbh',
#  'fates_allom_zroot_max_z',
#  'fates_allom_zroot_min_dbh',
#  'fates_allom_zroot_min_z',
#  'fates_branch_turnover',
#  'fates_c2b',
#  'fates_dev_arbitrary_pft',
#  'fates_displar',
#  'fates_eca_alpha_ptase',
#  'fates_eca_decompmicc',
#  'fates_eca_km_nh4',
#  'fates_eca_km_no3',
#  'fates_eca_km_p',
#  'fates_eca_km_ptase',
#  'fates_eca_lambda_ptase',
#  'fates_eca_vmax_nh4',
#  'fates_eca_vmax_no3',
#  'fates_eca_vmax_p',
#  'fates_eca_vmax_ptase',
#  'fates_fire_alpha_SH',
#  'fates_fire_bark_scaler',
#  'fates_fire_crown_depth_frac',
#  'fates_fire_crown_kill',
#  'fates_fnrt_prof_a',
#  'fates_fnrt_prof_b',
#  'fates_fnrt_prof_mode',
#  'fates_fr_fcel',
#  'fates_fr_flab',
#  'fates_fr_flig',
#  'fates_grperc',
#  'fates_hydr_avuln_gs',
#  'fates_hydr_avuln_node',
#  'fates_hydr_epsil_node',
#  'fates_hydr_fcap_node',
#  'fates_hydr_k_lwp',
#  'fates_hydr_kmax_node',
#  'fates_hydr_p50_gs',
#  'fates_hydr_p50_node',
#  'fates_hydr_p_taper',
#  'fates_hydr_pinot_node',
#  'fates_hydr_pitlp_node',
#  'fates_hydr_resid_node',
#  'fates_hydr_rfrac_stem',
#  'fates_hydr_rs2',
#  'fates_hydr_srl',
#  'fates_hydr_thetas_node',
#  'fates_hydr_vg_alpha_node',
#  'fates_hydr_vg_m_node',
#  'fates_hydr_vg_n_node',
#  'fates_leaf_c3psn',
#  'fates_leaf_clumping_index',
#  'fates_leaf_diameter',
#  'fates_leaf_jmaxha',
#  'fates_leaf_jmaxhd',
#  'fates_leaf_jmaxse',
#  'fates_leaf_long',
#  'fates_leaf_slamax',
#  'fates_leaf_slatop',
#  'fates_leaf_stomatal_intercept',
#  'fates_leaf_stomatal_slope_ballberry',
#  'fates_leaf_stomatal_slope_medlyn',
#  'fates_leaf_stor_priority',
#  'fates_leaf_vcmax25top',
#  'fates_leaf_vcmaxha',
#  'fates_leaf_vcmaxhd',
#  'fates_leaf_vcmaxse',
#  'fates_leaf_xl',
#  'fates_lf_fcel',
#  'fates_lf_flab',
#  'fates_lf_flig',
#  'fates_maintresp_reduction_curvature',
#  'fates_maintresp_reduction_intercept',
#  'fates_mort_bmort',
#  'fates_mort_freezetol',
#  'fates_mort_hf_flc_threshold',
#  'fates_mort_hf_sm_threshold',
#  'fates_mort_ip_age_senescence',
#  'fates_mort_ip_size_senescence',
#  'fates_mort_r_age_senescence',
#  'fates_mort_r_size_senescence',
#  'fates_mort_scalar_coldstress',
#  'fates_mort_scalar_cstarvation',
#  'fates_mort_scalar_hydrfailure',
#  'fates_nfix1',
#  'fates_nfix2',
#  'fates_nitr_store_ratio',
#  'fates_phen_cold_size_threshold',
#  'fates_phen_evergreen',
#  'fates_phen_season_decid',
#  'fates_phen_stem_drop_fraction',
#  'fates_phen_stress_decid',
#  'fates_phenflush_fraction',
#  'fates_phos_store_ratio',
#  'fates_prescribed_mortality_canopy',
#  'fates_prescribed_mortality_understory',
#  'fates_prescribed_npp_canopy',
#  'fates_prescribed_npp_understory',
#  'fates_prescribed_nuptake',
#  'fates_prescribed_puptake',
#  'fates_prescribed_recruitment',
#  'fates_prt_alloc_priority',
#  'fates_prt_nitr_stoich_p1',
#  'fates_prt_nitr_stoich_p2',
#  'fates_prt_phos_stoich_p1',
#  'fates_prt_phos_stoich_p2',
#  'fates_recruit_hgt_min',
#  'fates_recruit_initd',
#  'fates_rholnir',
#  'fates_rholvis',
#  'fates_rhosnir',
#  'fates_rhosvis',
#  'fates_root_long',
#  'fates_seed_alloc',
#  'fates_seed_alloc_mature',
#  'fates_seed_dbh_repro_threshold',
#  'fates_seed_decay_rate',
#  'fates_seed_germination_rate',
#  'fates_seed_suppl',
#  'fates_senleaf_long_fdrought',
#  'fates_smpsc',
#  'fates_smpso',
#  'fates_taulnir',
#  'fates_taulvis',
#  'fates_tausnir',
#  'fates_tausvis',
#  'fates_trim_inc',
#  'fates_trim_limit',
#  'fates_turnover_carb_retrans',
#  'fates_turnover_nitr_retrans',
#  'fates_turnover_phos_retrans',
#  'fates_turnover_retrans_mode',
#  'fates_wood_density',
#  'fates_woody',
#  'fates_z0mr',
#  'fates_hlm_pft_map',
#  'fates_fire_FBD',
#  'fates_fire_low_moisture_Coeff',
#  'fates_fire_low_moisture_Slope',
#  'fates_fire_mid_moisture',
#  'fates_fire_mid_moisture_Coeff',
#  'fates_fire_mid_moisture_Slope',
#  'fates_fire_min_moisture',
#  'fates_fire_SAV',
#  'fates_max_decomp',
#  'fates_CWD_frac',
#  'fates_base_mr_20',
#  'fates_canopy_closure_thresh',
#  'fates_cohort_age_fusion_tol',
#  'fates_cohort_size_fusion_tol',
#  'fates_comp_excln',
#  'fates_cwd_fcel',
#  'fates_cwd_flig',
#  'fates_dev_arbitrary',
#  'fates_eca_plant_escalar',
#  'fates_fire_active_crown_fire',
#  'fates_fire_cg_strikes',
#  'fates_fire_drying_ratio',
#  'fates_fire_durat_slope',
#  'fates_fire_fdi_a',
#  'fates_fire_fdi_alpha',
#  'fates_fire_fdi_b',
#  'fates_fire_fuel_energy',
#  'fates_fire_max_durat',
#  'fates_fire_miner_damp',
#  'fates_fire_miner_total',
#  'fates_fire_nignitions',
#  'fates_fire_part_dens',
#  'fates_fire_threshold',
#  'fates_hydr_kmax_rsurf1',
#  'fates_hydr_kmax_rsurf2',
#  'fates_hydr_psi0',
#  'fates_hydr_psicap',
#  'fates_init_litter',
#  'fates_leaf_stomatal_model',
#  'fates_logging_coll_under_frac',
#  'fates_logging_collateral_frac',
#  'fates_logging_dbhmax',
#  'fates_logging_dbhmax_infra',
#  'fates_logging_dbhmin',
#  'fates_logging_direct_frac',
#  'fates_logging_event_code',
#  'fates_logging_export_frac',
#  'fates_logging_mechanical_frac',
#  'fates_maintresp_model',
#  'fates_mort_disturb_frac',
#  'fates_mort_understorey_death',
#  'fates_patch_fusion_tol',
#  'fates_phen_a',
#  'fates_phen_b',
#  'fates_phen_c',
#  'fates_phen_chiltemp',
#  'fates_phen_coldtemp',
#  'fates_phen_doff_time',
#  'fates_phen_drought_threshold',
#  'fates_phen_mindayson',
#  'fates_phen_ncolddayslim',
#  'fates_photo_temp_acclim_timescale',
#  'fates_photo_tempsens_model',
#  'fates_q10_froz',
#  'fates_q10_mr',
#  'fates_soil_salinity',
#  'fates_theta_cj_c3',
#  'fates_theta_cj_c4',
#  'fates_vai_top_bin_width',
#  'fates_vai_width_increase_factor']
