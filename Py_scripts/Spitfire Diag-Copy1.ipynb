# %%
import xarray as xr
#import rioxarray as rxr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
### Plotting stuff 
plt.rc('figure', figsize=(12, 10))
CB91_Blue = '#2CBDFE'
CB91_Green = '#47DBCD'
CB91_Pink = '#F3A0F2'
CB91_Purple = '#9D2EC5'
CB91_Violet = '#661D98'
CB91_Amber = '#F5B14C'
CB_ex1='#8dd3c7'
CB_ex2='#bebada'
CB_ex3='#ffffb3'
CB_ex4='#fb8072'
CB_ex5='#fdb462'
color_list = [CB91_Blue, CB91_Pink, CB91_Green, CB91_Amber,
              CB91_Purple,CB_ex1,CB_ex2,CB_ex3,CB_ex4,CB_ex5,CB91_Violet]
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=color_list)
plt.rcParams.update({'font.size': 10})

# %%
def ProcessbyPAge(Data,Var,Time):
    out=pd.DataFrame({"Age"+str(Ages[0]):np.array(Data[Var][:,0]).flatten(),
              "Age"+str(Ages[1]):np.array(Data[Var][:,1]).flatten(),
              "Age"+str(Ages[2]):np.array(Data[Var][:,2]).flatten(),
              "Age"+str(Ages[3]):np.array(Data[Var][:,3]).flatten(),
              "Age"+str(Ages[4]):np.array(Data[Var][:,4]).flatten(),
              "Age"+ str(Ages[5]):np.array(Data[Var][:,5]).flatten(),
              "Age"+str(Ages[6]):np.array(Data[Var][:,6]).flatten()
              },index=Time)
    return(out)

def ProcessbyFuelClass(Data,Var,Time):
    out=pd.DataFrame({"FuelClass"+str(FuelClass[0]):np.array(Data[Var][:,0]).flatten(),
              "FuelClass"+str(FuelClass[1]):np.array(Data[Var][:,1]).flatten(),
              "FuelClass"+str(FuelClass[2]):np.array(Data[Var][:,2]).flatten(),
              "FuelClass"+str(FuelClass[3]):np.array(Data[Var][:,3]).flatten(),
              "FuelClass"+str(FuelClass[4]):np.array(Data[Var][:,4]).flatten(),
              "FuelClass"+str(FuelClass[5]):np.array(Data[Var][:,5]).flatten(),
              },index=Time)
    return(out)
def ProcesbyCanopyLay(Data,Var,Time):
    out=pd.DataFrame({"Understory"+str(Canopy[0]):np.array(Data[Var][:,0]).flatten(),
              "Canopy"+str(Canopy[1]):np.array(Data[Var][:,1]).flatten(),
              },index=Time)
    return(out)
def ProcesbyPFT(Data,Var,Time,PFT):
    out=pd.DataFrame({PFT[0]:np.array(Data[Var][:,0]).flatten(),
              PFT[1]:np.array(Data[Var][:,1]).flatten(),
              },index=Time)
    return(out)
def plotterage(data,titlelabel,xlabel,ylabel,legendloc):
    fig, ax = plt.subplots(figsize=(12, 10))
    plt.title(titlelabel, fontsize=20)
    plt.plot(data['Age0.0'],label="Age 0.0")
    plt.plot(data['Age1.0'],label="Age 1.0")
    plt.plot(data['Age2.0'],label="Age 2.0")
    plt.plot(data['Age5.0'],label="Age 5.0")
    plt.plot(data['Age10.0'],label="Age 10.0")
    plt.plot(data['Age20.0'],label="Age 20.0")
    plt.plot(data['Age50.0'],label="Age 50.0")
    ax.set_xlabel(xlabel, labelpad=15, fontsize=20, color="#333533");
    ax.set_ylabel(ylabel, labelpad=15, fontsize=20, color="#333533");
    plt.legend(bbox_to_anchor=(1.04,1), loc="upper left",prop={'size': 20})
    
def plottercan(data,titlelabel,xlabel,ylabel,legendloc):
    fig, ax = plt.subplots(figsize=(12, 10))
    plt.title(titlelabel, fontsize=20)
    plt.plot(data['Understory1'],label="Understory")
    plt.plot(data['Canopy2'],label="Overstory")
    ax.set_xlabel(xlabel, labelpad=15, fontsize=20, color="#333533");
    ax.set_ylabel(ylabel, labelpad=15, fontsize=20, color="#333533");
    plt.legend(bbox_to_anchor=(1.04,1), loc="upper left",prop={'size': 20})

def plottercan(data,titlelabel,xlabel,ylabel,legendloc):
    fig, ax = plt.subplots(figsize=(12, 10))
    plt.title(titlelabel, fontsize=20)
    plt.plot(data['Understory1'],label="Understory")
    plt.plot(data['Canopy2'],label="Overstory")
    ax.set_xlabel(xlabel, labelpad=15, fontsize=20, color="#333533");
    ax.set_ylabel(ylabel, labelpad=15, fontsize=20, color="#333533");
    plt.legend(bbox_to_anchor=(1.04,1), loc="upper left",prop={'size': 20})
    
    
def plotterpft(data,PFT,titlelabel,xlabel,ylabel):
    fig, ax = plt.subplots(figsize=(12, 10))
    plt.title(titlelabel, fontsize=20)
    plt.plot(data[PFT[0]],label=PFT[0])
    plt.plot(data[PFT[1]],label=PFT[1])
    ax.set_xlabel(xlabel, labelpad=15, fontsize=20, color="#333533");
    ax.set_ylabel(ylabel, labelpad=15, fontsize=20, color="#333533");
    plt.legend(bbox_to_anchor=(1.04,1),prop={'size': 20})

# %%
data_path = "C:/Users/345578/Documents/GitHub/Transfer_HPC/Fuels3.nc"

Fates_xr  = xr.open_dataset(data_path)  
### Set up labels 
test=Fates_xr.coords['time'].values
#print()
#Fates_xr=Fates_xr.isel(time=slice(0,np.int(len(test)/2)))

#Fates_xr=Fates_xr.isel(time=slice(240,260))
### Set up labels 
Ages=Fates_xr.coords['fates_levage'].values
Time=Fates_xr.indexes['time'].to_datetimeindex()
FuelClass=Fates_xr.indexes['fates_levfuel'].values  
Canopy=Fates_xr.indexes['fates_levcan'].values  
nscls_bins = len(Fates_xr.variables['fates_levscls'])
npfts = len(Fates_xr.variables['fates_levpft'])
nage_bins = len(Fates_xr.variables['fates_levage'])
print(Time)
# Out:
# DatetimeIndex(['1950-02-01', '1950-03-01', '1950-04-01', '1950-05-01',
#                '1950-06-01', '1950-07-01', '1950-08-01', '1950-09-01',
#                '1950-10-01', '1950-11-01',
#                ...
#                '1959-04-01', '1959-05-01', '1959-06-01', '1959-07-01',
#                '1959-08-01', '1959-09-01', '1959-10-01', '1959-11-01',
#                '1959-12-01', '1960-01-01'],
#               dtype='datetime64[ns]', length=120, freq=None)
# <ipython-input-19-e81f3bc21a1a>:12: RuntimeWarning: Converting a CFTimeIndex with dates from a non-standard calendar, 'noleap', to a pandas.DatetimeIndex, which uses dates from the standard calendar.  This may lead to subtle errors in operations that depend on the length of time between dates.
#   Time=Fates_xr.indexes['time'].to_datetimeindex()

# %%
list(Fates_xr.keys())
# Out:
# ['fates_scmap_levscag',
#  'fates_agmap_levscag',
#  'fates_pftmap_levscpf',
#  'fates_scmap_levscpf',
#  'fates_pftmap_levcapf',
#  'fates_camap_levcapf',
#  'fates_canmap_levcnlf',
#  'fates_lfmap_levcnlf',
#  'fates_canmap_levcnlfpf',
#  'fates_lfmap_levcnlfpf',
#  'fates_pftmap_levcnlfpf',
#  'fates_scmap_levscagpft',
#  'fates_agmap_levscagpft',
#  'fates_pftmap_levscagpft',
#  'fates_pftmap_levagepft',
#  'fates_agmap_levagepft',
#  'fates_elmap_levelpft',
#  'fates_pftmap_levelpft',
#  'fates_elmap_levelcwd',
#  'fates_cwdmap_levelcwd',
#  'fates_elmap_levelage',
#  'fates_agemap_levelage',
#  'fates_agmap_levagefuel',
#  'fates_fscmap_levagefuel',
#  'mcdate',
#  'mcsec',
#  'mdcur',
#  'mscur',
#  'nstep',
#  'time_bounds',
#  'date_written',
#  'time_written',
#  'lon',
#  'lat',
#  'area',
#  'topo',
#  'landfrac',
#  'landmask',
#  'pftmask',
#  'ZSOI',
#  'DZSOI',
#  'WATSAT',
#  'SUCSAT',
#  'BSW',
#  'HKSAT',
#  'ZLAKE',
#  'DZLAKE',
#  'ACTUAL_IMMOB',
#  'ACTUAL_IMMOB_P',
#  'ADSORBTION_P',
#  'AGB',
#  'AGB_SCLS',
#  'AR',
#  'AREA_BURNT_BY_PATCH_AGE',
#  'AREA_PLANT',
#  'AREA_TREES',
#  'AR_CANOPY',
#  'AR_UNDERSTORY',
#  'BA_SCLS',
#  'BCDEP',
#  'BIOCHEM_PMIN',
#  'BIOCHEM_PMIN_TO_PLANT',
#  'BIOMASS_CANOPY',
#  'BIOMASS_UNDERSTORY',
#  'BTRAN',
#  'BUILDHEAT',
#  'BURNT_LITTER_FRAC_AREA_PRODUCT',
#  'CANOPY_AREA_BY_AGE',
#  'CANOPY_HEIGHT_DIST',
#  'CANOPY_SPREAD',
#  'CBALANCE_ERROR_FATES',
#  'CEFFLUX',
#  'CMASS_BALANCE_ERROR',
#  'COL_PTRUNC',
#  'CROWNAREA_CAN',
#  'CWDC',
#  'CWDC_vr',
#  'CWDN',
#  'CWDN_TO_LITR2N',
#  'CWDN_TO_LITR3N',
#  'CWDN_vr',
#  'CWDP',
#  'CWDP_TO_LITR2P',
#  'CWDP_TO_LITR3P',
#  'CWDP_vr',
#  'C_LBLAYER',
#  'C_STOMATA',
#  'DDBH_CANOPY_SCLS',
#  'DDBH_UNDERSTORY_SCLS',
#  'DEFICIT',
#  'DEMOTION_CARBONFLUX',
#  'DENIT',
#  'DESORPTION_P',
#  'DISTURBANCE_RATE_FIRE',
#  'DISTURBANCE_RATE_LOGGING',
#  'DISTURBANCE_RATE_P2P',
#  'DISTURBANCE_RATE_P2S',
#  'DISTURBANCE_RATE_POTENTIAL',
#  'DISTURBANCE_RATE_S2S',
#  'DISTURBANCE_RATE_TREEFALL',
#  'DSTDEP',
#  'DSTFLXT',
#  'DWB',
#  'DWT_CONV_NFLUX_GRC',
#  'DWT_CONV_PFLUX_GRC',
#  'DWT_SLASH_NFLUX',
#  'DWT_SLASH_PFLUX',
#  'ED_NCOHORTS',
#  'ED_NPATCHES',
#  'ED_balive',
#  'ED_bdead',
#  'ED_bfineroot',
#  'ED_biomass',
#  'ED_bleaf',
#  'ED_bsapwood',
#  'ED_bstore',
#  'EFFECT_WSPEED',
#  'EFLX_DYNBAL',
#  'EFLX_GRND_LAKE',
#  'EFLX_LH_TOT',
#  'EFLX_LH_TOT_R',
#  'EFLX_LH_TOT_U',
#  'ELAI',
#  'ERRH2O',
#  'ERRH2OSNO',
#  'ERROR_FATES',
#  'ERRSEB',
#  'ERRSOI',
#  'ERRSOL',
#  'ESAI',
#  'FATES_HR',
#  'FCEV',
#  'FCOV',
#  'FCTR',
#  'FGEV',
#  'FGR',
#  'FGR12',
#  'FGR_R',
#  'FGR_U',
#  'FH2OSFC',
#  'FIRA',
#  'FIRA_R',
#  'FIRA_U',
#  'FIRE',
#  'FIRE_AREA',
#  'FIRE_FDI',
#  'FIRE_FLUX',
#  'FIRE_FUEL_BULKD',
#  'FIRE_FUEL_EFF_MOIST',
#  'FIRE_FUEL_MEF',
#  'FIRE_FUEL_SAV',
#  'FIRE_IGNITIONS',
#  'FIRE_INTENSITY',
#  'FIRE_INTENSITY_AREA_PRODUCT',
#  'FIRE_INTENSITY_BY_PATCH_AGE',
#  'FIRE_NESTEROV_INDEX',
#  'FIRE_R',
#  'FIRE_ROS',
#  'FIRE_ROS_AREA_PRODUCT',
#  'FIRE_TFC_ROS',
#  'FIRE_TFC_ROS_AREA_PRODUCT',
#  'FIRE_U',
#  'FLDS',
#  'FNRTC',
#  'FPSN',
#  'FPSN_WC',
#  'FPSN_WJ',
#  'FPSN_WP',
#  'FRAGMENTATION_SCALER_SL',
#  'FROOT_MR',
#  'FROST_TABLE',
#  'FSA',
#  'FSAT',
#  'FSA_R',
#  'FSA_U',
#  'FSDS',
#  'FSDSND',
#  'FSDSNDLN',
#  'FSDSNI',
#  'FSDSVD',
#  'FSDSVDLN',
#  'FSDSVI',
#  'FSDSVILN',
#  'FSH',
#  'FSH_G',
#  'FSH_NODYNLNDUSE',
#  'FSH_R',
#  'FSH_U',
#  'FSH_V',
#  'FSM',
#  'FSM_R',
#  'FSM_U',
#  'FSNO',
#  'FSNO_EFF',
#  'FSR',
#  'FSRND',
#  'FSRNDLN',
#  'FSRNI',
#  'FSRVD',
#  'FSRVDLN',
#  'FSRVI',
#  'FUEL_AMOUNT_AGEFUEL',
#  'FUEL_AMOUNT_BY_NFSC',
#  'FUEL_MOISTURE_NFSC',
#  'F_DENIT',
#  'F_DENIT_vr',
#  'F_N2O_DENIT',
#  'F_N2O_NIT',
#  'F_NIT',
#  'F_NIT_vr',
#  'Fire_Closs',
#  'GC_HEAT1',
#  'GC_ICE1',
#  'GC_LIQ1',
#  'GPP',
#  'GPP_CANOPY',
#  'GPP_UNDERSTORY',
#  'GROSS_NMIN',
#  'GROSS_PMIN',
#  'GROWTH_RESP',
#  'H2OCAN',
#  'H2OSFC',
#  'H2OSNO',
#  'H2OSNO_TOP',
#  'H2OSOI',
#  'HARVEST_CARBON_FLUX',
#  'HC',
#  'HCSOI',
#  'HEAT_FROM_AC',
#  'HR',
#  'HR_vr',
#  'HTOP',
#  'INT_SNOW',
#  'LABILEP',
#  'LABILEP_TO_SECONDP',
#  'LABILEP_vr',
#  'LAISHA',
#  'LAISUN',
#  'LAI_BY_AGE',
#  'LAI_CANOPY_SCLS',
#  'LAI_UNDERSTORY_SCLS',
#  'LAKEICEFRAC',
#  'LAKEICETHICK',
#  'LEAFC',
#  'LEAF_HEIGHT_DIST',
#  'LEAF_MR',
#  'LITHR',
#  'LITR1C',
#  'LITR1C_vr',
#  'LITR1N',
#  'LITR1N_TNDNCY_VERT_TRANS',
#  'LITR1N_TO_SOIL1N',
#  'LITR1N_vr',
#  'LITR1P',
#  'LITR1P_TNDNCY_VERT_TRANS',
#  'LITR1P_TO_SOIL1P',
#  'LITR1P_vr',
#  'LITR2C',
#  'LITR2C_vr',
#  'LITR2N',
#  'LITR2N_TNDNCY_VERT_TRANS',
#  'LITR2N_TO_SOIL2N',
#  'LITR2N_vr',
#  'LITR2P',
#  'LITR2P_TNDNCY_VERT_TRANS',
#  'LITR2P_TO_SOIL2P',
#  'LITR2P_vr',
#  'LITR3C',
#  'LITR3C_vr',
#  'LITR3N',
#  'LITR3N_TNDNCY_VERT_TRANS',
#  'LITR3N_TO_SOIL3N',
#  'LITR3N_vr',
#  'LITR3P',
#  'LITR3P_TNDNCY_VERT_TRANS',
#  'LITR3P_TO_SOIL3P',
#  'LITR3P_vr',
#  'LITTERC',
#  'LITTER_CWD',
#  'LITTER_CWD_AG_ELEM',
#  'LITTER_CWD_BG_ELEM',
#  'LITTER_FINES_AG_ELEM',
#  'LITTER_FINES_BG_ELEM',
#  'LITTER_IN',
#  'LITTER_IN_ELEM',
#  'LITTER_OUT',
#  'LITTER_OUT_ELEM',
#  'LIVECROOT_MR',
#  'LIVESTEM_MR',
#  'M10_CACLS',
#  'M10_SCLS',
#  'M1_SCLS',
#  'M2_SCLS',
#  'M3_SCLS',
#  'M4_SCLS',
#  'M5_SCLS',
#  'M6_SCLS',
#  'M7_SCLS',
#  'M8_SCLS',
#  'M9_SCLS',
#  'MAINT_RESP',
#  'MORTALITY',
#  'MORTALITY_CANOPY_SCLS',
#  'MORTALITY_CARBONFLUX_CANOPY',
#  'MORTALITY_CARBONFLUX_UNDERSTORY',
#  'MORTALITY_UNDERSTORY_SCLS',
#  'NDEP_TO_SMINN',
#  'NEP',
#  'NET_NMIN',
#  'NET_PMIN',
#  'NFIX_TO_SMINN',
#  'NPLANT_CACLS',
#  'NPLANT_CANOPY_SCLS',
#  'NPLANT_SCAG',
#  'NPLANT_SCLS',
#  'NPLANT_UNDERSTORY_SCLS',
#  'NPP',
#  'NPP_CROOT',
#  'NPP_FROOT',
#  'NPP_LEAF',
#  'NPP_SEED',
#  'NPP_STEM',
#  'NPP_STOR',
#  'OCCLP',
#  'OCCLP_vr',
#  'OCDEP',
#  'PARVEGLN',
#  'PATCH_AREA_BY_AGE',
#  'PBOT',
#  'PCO2',
#  'PCT_LANDUNIT',
#  'PCT_NAT_PFT',
#  'PDEP_TO_SMINP',
#  'PFTbiomass',
#  'PFTgpp',
#  'PFTleafbiomass',
#  'PFTnindivs',
#  'PFTnpp',
#  'PFTstorebiomass',
#  'PLANT_NDEMAND_COL',
#  'PLANT_PDEMAND_COL',
#  'POTENTIAL_IMMOB',
#  'POTENTIAL_IMMOB_P',
#  'POT_F_DENIT',
#  'POT_F_NIT',
#  'PRIMARYLAND_PATCHFUSION_ERROR',
#  'PRIMP',
#  'PRIMP_TO_LABILEP',
#  'PRIMP_vr',
#  'PROD1P_LOSS',
#  'PROMOTION_CARBONFLUX',
#  'Q2M',
#  'QBOT',
#  'QCHARGE',
#  'QDRAI',
#  'QDRAI_PERCH',
#  'QDRAI_XS',
#  'QDRIP',
#  'QFLOOD',
#  'QFLX_ICE_DYNBAL',
#  'QFLX_LIQ_DYNBAL',
#  'QH2OSFC',
#  'QINFL',
#  'QINTR',
#  'QIRRIG_GRND',
#  'QIRRIG_ORIG',
#  'QIRRIG_REAL',
#  'QIRRIG_SURF',
#  'QIRRIG_WM',
#  'QOVER',
#  'QRGWL',
#  'QRUNOFF',
#  'QRUNOFF_NODYNLNDUSE',
#  'QRUNOFF_R',
#  'QRUNOFF_U',
#  'QSNOMELT',
#  'QSNWCPICE',
#  'QSNWCPICE_NODYNLNDUSE',
#  'QSOIL',
#  'QVEGE',
#  'QVEGT',
#  'RAIN',
#  'RECRUITMENT',
#  'REPROC',
#  'RH2M',
#  'RH2M_R',
#  'RH2M_U',
#  'SABG',
#  'SABG_PEN',
#  'SABV',
#  'SAPWC',
#  'SCORCH_HEIGHT',
#  'SECONDP',
#  'SECONDP_TO_LABILEP',
#  'SECONDP_TO_OCCLP',
#  'SECONDP_vr',
#  'SEEDS_IN',
#  'SEEDS_IN_EXTERN_ELEM',
#  'SEEDS_IN_LOCAL_ELEM',
#  'SEED_BANK',
#  'SEED_BANK_ELEM',
#  'SEED_DECAY_ELEM',
#  'SEED_GERM_ELEM',
#  'SITE_COLD_STATUS',
#  'SITE_DAYSINCE_COLDLEAFOFF',
#  'SITE_DAYSINCE_COLDLEAFON',
#  'SITE_DAYSINCE_DROUGHTLEAFOFF',
#  'SITE_DAYSINCE_DROUGHTLEAFON',
#  'SITE_DROUGHT_STATUS',
#  'SITE_GDD',
#  'SITE_MEANLIQVOL_DROUGHTPHEN',
#  'SITE_NCHILLDAYS',
#  'SITE_NCOLDDAYS',
#  'SMINN',
#  'SMINN_TO_PLANT',
#  'SMINN_TO_SOIL1N_L1',
#  'SMINN_TO_SOIL2N_L2',
#  'SMINN_TO_SOIL2N_S1',
#  'SMINN_TO_SOIL3N_L3',
#  'SMINN_TO_SOIL3N_S2',
#  'SMINN_TO_SOIL4N_S3',
#  'SMINP',
#  'SMINP_LEACHED',
#  'SMINP_TO_PLANT',
#  'SMINP_TO_SOIL1P_L1',
#  'SMINP_TO_SOIL2P_L2',
#  'SMINP_TO_SOIL2P_S1',
#  'SMINP_TO_SOIL3P_L3',
#  'SMINP_TO_SOIL3P_S2',
#  'SMINP_TO_SOIL4P_S3',
#  'SMINP_vr',
#  'SMIN_NH4',
#  'SMIN_NH4_vr',
#  'SMIN_NO3',
#  'SMIN_NO3_LEACHED',
#  'SMIN_NO3_RUNOFF',
#  'SMIN_NO3_vr',
#  'SNOBCMCL',
#  'SNOBCMSL',
#  'SNODSTMCL',
#  'SNODSTMSL',
#  'SNOINTABS',
#  'SNOOCMCL',
#  'SNOOCMSL',
#  'SNOW',
#  'SNOWDP',
#  'SNOWICE',
#  'SNOWLIQ',
#  'SNOW_DEPTH',
#  'SNOW_SINKS',
#  'SNOW_SOURCES',
#  'SOIL1C',
#  'SOIL1C_vr',
#  'SOIL1N',
#  'SOIL1N_TNDNCY_VERT_TRANS',
#  'SOIL1N_TO_SOIL2N',
#  'SOIL1N_vr',
#  'SOIL1P',
#  'SOIL1P_TNDNCY_VERT_TRANS',
#  'SOIL1P_TO_SOIL2P',
#  'SOIL1P_vr',
#  'SOIL2C',
#  'SOIL2C_vr',
#  'SOIL2N',
#  'SOIL2N_TNDNCY_VERT_TRANS',
#  'SOIL2N_TO_SOIL3N',
#  'SOIL2N_vr',
#  'SOIL2P',
#  'SOIL2P_TNDNCY_VERT_TRANS',
#  'SOIL2P_TO_SOIL3P',
#  'SOIL2P_vr',
#  'SOIL3C',
#  'SOIL3C_vr',
#  'SOIL3N',
#  'SOIL3N_TNDNCY_VERT_TRANS',
#  'SOIL3N_TO_SOIL4N',
#  'SOIL3N_vr',
#  'SOIL3P',
#  'SOIL3P_TNDNCY_VERT_TRANS',
#  'SOIL3P_TO_SOIL4P',
#  'SOIL3P_vr',
#  'SOIL4C',
#  'SOIL4C_vr',
#  'SOIL4N',
#  'SOIL4N_TNDNCY_VERT_TRANS',
#  'SOIL4N_TO_SMINN',
#  'SOIL4N_vr',
#  'SOIL4P',
#  'SOIL4P_TNDNCY_VERT_TRANS',
#  'SOIL4P_TO_SMINP',
#  'SOIL4P_vr',
#  'SOILC',
#  'SOILICE',
#  'SOILICE_ICE',
#  'SOILLIQ',
#  'SOILLIQ_ICE',
#  'SOILPSI',
#  'SOILWATER_10CM',
#  'SOLUTIONP',
#  'SOLUTIONP_vr',
#  'SOMHR',
#  'SOM_C_LEACHED',
#  'STOREC',
#  'SUM_FUEL',
#  'SUM_FUEL_BY_PATCH_AGE',
#  'SUPPLEMENT_TO_SMINN',
#  'SUPPLEMENT_TO_SMINP',
#  'SUPPLY',
#  'SoilAlpha',
#  'SoilAlpha_U',
#  'TAUX',
#  'TAUY',
#  'TBOT',
#  'TBUILD',
#  'TCS_MONTH_BEGIN',
#  'TCS_MONTH_END',
#  'TG',
#  'TG_R',
#  'TG_U',
#  'TH2OSFC',
#  'THBOT',
#  'TKE1',
#  'TLAI',
#  'TLAKE',
#  'TOTCOLC',
#  'TOTCOLN',
#  'TOTCOLP',
#  'TOTECOSYSC',
#  'TOTECOSYSN',
#  'TOTECOSYSP',
#  'TOTLITC',
#  'TOTLITC_1m',
#  'TOTLITN',
#  'TOTLITP',
#  'TOTLITP_1m',
#  'TOTSOMC',
#  'TOTSOMC_1m',
#  'TOTSOMN',
#  'TOTSOMP',
#  'TOTSOMP_1m',
#  'TOTVEGC',
#  'TREFMNAV',
#  'TREFMNAV_R',
#  'TREFMNAV_U',
#  'TREFMXAV',
#  'TREFMXAV_R',
#  'TREFMXAV_U',
#  'TRIMMING',
#  'TSA',
#  'TSAI',
#  'TSA_R',
#  'TSA_U',
#  'TSOI',
#  'TSOI_10CM',
#  'TSOI_ICE',
#  'TV',
#  'TWS',
#  'TWS_MONTH_BEGIN',
#  'TWS_MONTH_END',
#  'U10',
#  'URBAN_AC',
#  'URBAN_HEAT',
#  'VOLR',
#  'VOLRMCH',
#  'WA',
#  'WASTEHEAT',
#  'WIND',
#  'ZBOT',
#  'ZSTAR_BY_AGE',
#  'ZWT',
#  'ZWT_PERCH']

# %%
'FIRE_AREA''area'
Fates_xr['C_STOMATA'].attrs
# Out:
# 'FIRE_AREAarea'
# {'long_name': 'mean stomatal conductance',
#  'units': 'umol m-2 s-1',
#  'cell_methods': 'time: mean'}

# %%
for i in Fates_xr.keys():
    print(i)
    print(Fates_xr[i].attrs)
# Out:
# fates_scmap_levscag
# {'long_name': 'FATES size-class map into size x patch age', 'units': '-'}
# fates_agmap_levscag
# {'long_name': 'FATES age-class map into size x patch age', 'units': '-'}
# fates_pftmap_levscpf
# {'long_name': 'FATES pft index of the combined pft-size class dimension', 'units': '-'}
# fates_scmap_levscpf
# {'long_name': 'FATES size index of the combined pft-size class dimension', 'units': '-'}
# fates_pftmap_levcapf
# {'long_name': 'FATES pft index of the combined pft-cohort age class dimension', 'units': '-'}
# fates_camap_levcapf
# {'long_name': 'FATES cohort age index of the combined pft-cohort age dimension', 'units': '-'}
# fates_canmap_levcnlf
# {'long_name': 'FATES canopy level of combined canopy-leaf dimension'}
# fates_lfmap_levcnlf
# {'long_name': 'FATES leaf level of combined canopy-leaf dimension'}
# fates_canmap_levcnlfpf
# {'long_name': 'FATES canopy level of combined canopy x leaf x pft dimension'}
# fates_lfmap_levcnlfpf
# {'long_name': 'FATES leaf level of combined canopy x leaf x pft dimension'}
# fates_pftmap_levcnlfpf
# {'long_name': 'FATES PFT level of combined canopy x leaf x pft dimension'}
# fates_scmap_levscagpft
# {'long_name': 'FATES size-class map into size x patch age x pft', 'units': '-'}
# fates_agmap_levscagpft
# {'long_name': 'FATES age-class map into size x patch age x pft', 'units': '-'}
# fates_pftmap_levscagpft
# {'long_name': 'FATES pft map into size x patch age x pft', 'units': '-'}
# fates_pftmap_levagepft
# {'long_name': 'FATES pft map into patch age x pft', 'units': '-'}
# fates_agmap_levagepft
# {'long_name': 'FATES age-class map into patch age x pft', 'units': '-'}
# fates_elmap_levelpft
# {'long_name': 'FATES element map into element x pft', 'units': '-'}
# fates_pftmap_levelpft
# {'long_name': 'FATES pft map into element x pft', 'units': '-'}
# fates_elmap_levelcwd
# {'long_name': 'FATES element map into element x cwd', 'units': '-'}
# fates_cwdmap_levelcwd
# {'long_name': 'FATES cwd map into element x cwd', 'units': '-'}
# fates_elmap_levelage
# {'long_name': 'FATES element map into age x pft', 'units': '-'}
# fates_agemap_levelage
# {'long_name': 'FATES element map into age x pft', 'units': '-'}
# fates_agmap_levagefuel
# {'long_name': 'FATES age-class map into patch age x fuel size', 'units': '-'}
# fates_fscmap_levagefuel
# {'long_name': 'FATES fuel size-class map into patch age x fuel size', 'units': '-'}
# mcdate
# {'long_name': 'current date (YYYYMMDD)'}
# mcsec
# {'long_name': 'current seconds of current date', 'units': 's'}
# mdcur
# {'long_name': 'current day (from base day)'}
# mscur
# {'long_name': 'current seconds of current day'}
# nstep
# {'long_name': 'time step'}
# time_bounds
# {'long_name': 'history time interval endpoints'}
# date_written
# {}
# time_written
# {}
# lon
# {'long_name': 'coordinate longitude', 'units': 'degrees_east'}
# lat
# {'long_name': 'coordinate latitude', 'units': 'degrees_north'}
# area
# {'long_name': 'grid cell areas', 'units': 'km^2'}
# topo
# {'long_name': 'grid cell topography', 'units': 'm'}
# landfrac
# {'long_name': 'land fraction'}
# landmask
# {'long_name': 'land/ocean mask (0.=ocean and 1.=land)'}
# pftmask
# {'long_name': 'pft real/fake mask (0.=fake and 1.=real)'}
# ZSOI
# {'long_name': 'soil depth', 'units': 'm'}
# DZSOI
# {'long_name': 'soil thickness', 'units': 'm'}
# WATSAT
# {'long_name': 'saturated soil water content (porosity)', 'units': 'mm3/mm3'}
# SUCSAT
# {'long_name': 'saturated soil matric potential', 'units': 'mm'}
# BSW
# {'long_name': 'slope of soil water retention curve', 'units': '1'}
# HKSAT
# {'long_name': 'saturated hydraulic conductivity', 'units': '1'}
# ZLAKE
# {'long_name': 'lake layer node depth', 'units': 'm'}
# DZLAKE
# {'long_name': 'lake layer thickness', 'units': 'm'}
# ACTUAL_IMMOB
# {'long_name': 'actual N immobilization', 'units': 'gN/m^2/s', 'cell_methods': 'time: mean'}
# ACTUAL_IMMOB_P
# {'long_name': 'actual P immobilization', 'units': 'gP/m^2/s', 'cell_methods': 'time: mean'}
# ADSORBTION_P
# {'long_name': 'adsorb P flux', 'units': 'gP/m^2/s', 'cell_methods': 'time: mean'}
# AGB
# {'long_name': 'Aboveground biomass', 'units': 'gC m-2', 'cell_methods': 'time: mean'}
# AGB_SCLS
# {'long_name': 'Aboveground biomass by size class', 'units': 'kgC/m2', 'cell_methods': 'time: mean'}
# AR
# {'long_name': 'autotrophic respiration', 'units': 'gC/m^2/s', 'cell_methods': 'time: mean'}
# AREA_BURNT_BY_PATCH_AGE
# {'long_name': 'spitfire area burnt by patch age (divide by patch_area_by_age to get burnt fraction by age)', 'units': 'm2/m2/day', 'cell_methods': 'time: mean'}
# AREA_PLANT
# {'long_name': 'area occupied by all plants', 'units': 'm2/m2', 'cell_methods': 'time: mean'}
# AREA_TREES
# {'long_name': 'area occupied by woody plants', 'units': 'm2/m2', 'cell_methods': 'time: mean'}
# AR_CANOPY
# {'long_name': 'autotrophic respiration of canopy plants', 'units': 'gC/m^2/s', 'cell_methods': 'time: mean'}
# AR_UNDERSTORY
# {'long_name': 'autotrophic respiration of understory plants', 'units': 'gC/m^2/s', 'cell_methods': 'time: mean'}
# BA_SCLS
# {'long_name': 'basal area by size class', 'units': 'm2/ha', 'cell_methods': 'time: mean'}
# BCDEP
# {'long_name': 'total BC deposition (dry+wet) from atmosphere', 'units': 'kg/m^2/s', 'cell_methods': 'time: mean'}
# BIOCHEM_PMIN
# {'long_name': 'biochemical rate of P mineralization', 'units': 'gP/m^2/s', 'cell_methods': 'time: mean'}
# BIOCHEM_PMIN_TO_PLANT
# {'long_name': 'plant uptake of biochemical P mineralization', 'units': 'gP/m^2/s', 'cell_methods': 'time: mean'}
# BIOMASS_CANOPY
# {'long_name': 'Biomass of canopy plants', 'units': 'gC m-2', 'cell_methods': 'time: mean'}
# BIOMASS_UNDERSTORY
# {'long_name': 'Biomass of understory plants', 'units': 'gC m-2', 'cell_methods': 'time: mean'}
# BTRAN
# {'long_name': 'transpiration beta factor', 'units': '1', 'cell_methods': 'time: mean'}
# BUILDHEAT
# {'long_name': 'heat flux from urban building interior to walls and roof', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# BURNT_LITTER_FRAC_AREA_PRODUCT
# {'long_name': 'product of fraction of fuel burnt and burned area (divide by FIRE_AREA to get burned-area-weighted mean fraction fuel burnt)', 'units': 'fraction', 'cell_methods': 'time: mean'}
# CANOPY_AREA_BY_AGE
# {'long_name': 'canopy area by age bin', 'units': 'm2/m2', 'cell_methods': 'time: mean'}
# CANOPY_HEIGHT_DIST
# {'long_name': 'canopy height distribution', 'units': 'm2/m2', 'cell_methods': 'time: mean'}
# CANOPY_SPREAD
# {'long_name': 'Scaling factor between tree basal area and canopy area', 'units': '0-1', 'cell_methods': 'time: mean'}
# CBALANCE_ERROR_FATES
# {'long_name': 'total carbon error, FATES', 'units': 'mgC/day', 'cell_methods': 'time: mean'}
# CEFFLUX
# {'long_name': 'carbon efflux, root to soil', 'units': 'kgC/ha/day', 'cell_methods': 'time: mean'}
# CMASS_BALANCE_ERROR
# {'long_name': 'Gridcell carbon mass balance error', 'units': 'gC/m^2', 'cell_methods': 'time: mean'}
# COL_PTRUNC
# {'long_name': 'column-level sink for P truncation', 'units': 'gP/m^2', 'cell_methods': 'time: mean'}
# CROWNAREA_CAN
# {'long_name': 'total crown area in each canopy layer', 'units': 'm2/m2', 'cell_methods': 'time: mean'}
# CWDC
# {'long_name': 'CWD C', 'units': 'gC/m^2', 'cell_methods': 'time: mean'}
# CWDC_vr
# {'long_name': 'CWD C (vertically resolved)', 'units': 'gC/m^3', 'cell_methods': 'time: mean'}
# CWDN
# {'long_name': 'CWD N', 'units': 'gN/m^2', 'cell_methods': 'time: mean'}
# CWDN_TO_LITR2N
# {'long_name': 'decomp. of coarse woody debris N to litter 2 N', 'units': 'gN/m^2', 'cell_methods': 'time: mean'}
# CWDN_TO_LITR3N
# {'long_name': 'decomp. of coarse woody debris N to litter 3 N', 'units': 'gN/m^2', 'cell_methods': 'time: mean'}
# CWDN_vr
# {'long_name': 'CWD N (vertically resolved)', 'units': 'gN/m^3', 'cell_methods': 'time: mean'}
# CWDP
# {'long_name': 'CWD P', 'units': 'gP/m^2', 'cell_methods': 'time: mean'}
# CWDP_TO_LITR2P
# {'long_name': 'decomp. of coarse woody debris P to litter 2 N', 'units': 'gP/m^2', 'cell_methods': 'time: mean'}
# CWDP_TO_LITR3P
# {'long_name': 'decomp. of coarse woody debris P to litter 3 N', 'units': 'gP/m^2', 'cell_methods': 'time: mean'}
# CWDP_vr
# {'long_name': 'CWD P (vertically resolved)', 'units': 'gP/m^3', 'cell_methods': 'time: mean'}
# C_LBLAYER
# {'long_name': 'mean leaf boundary layer conductance', 'units': 'umol m-2 s-1', 'cell_methods': 'time: mean'}
# C_STOMATA
# {'long_name': 'mean stomatal conductance', 'units': 'umol m-2 s-1', 'cell_methods': 'time: mean'}
# DDBH_CANOPY_SCLS
# {'long_name': 'diameter growth increment by pft/size', 'units': 'cm/yr/ha', 'cell_methods': 'time: mean'}
# DDBH_UNDERSTORY_SCLS
# {'long_name': 'diameter growth increment by pft/size', 'units': 'cm/yr/ha', 'cell_methods': 'time: mean'}
# DEFICIT
# {'long_name': 'runoff supply deficit', 'units': 'mm/s', 'cell_methods': 'time: mean'}
# DEMOTION_CARBONFLUX
# {'long_name': 'demotion-associated biomass carbon flux from canopy to understory', 'units': 'gC/m2/s', 'cell_methods': 'time: mean'}
# DENIT
# {'long_name': 'total rate of denitrification', 'units': 'gN/m^2/s', 'cell_methods': 'time: mean'}
# DESORPTION_P
# {'long_name': 'desorp P flux', 'units': 'gP/m^2/s', 'cell_methods': 'time: mean'}
# DISTURBANCE_RATE_FIRE
# {'long_name': 'Disturbance rate from fire', 'units': 'm2 m-2 d-1', 'cell_methods': 'time: mean'}
# DISTURBANCE_RATE_LOGGING
# {'long_name': 'Disturbance rate from logging', 'units': 'm2 m-2 d-1', 'cell_methods': 'time: mean'}
# DISTURBANCE_RATE_P2P
# {'long_name': 'Disturbance rate from primary to primary lands', 'units': 'm2 m-2 d-1', 'cell_methods': 'time: mean'}
# DISTURBANCE_RATE_P2S
# {'long_name': 'Disturbance rate from primary to secondary lands', 'units': 'm2 m-2 d-1', 'cell_methods': 'time: mean'}
# DISTURBANCE_RATE_POTENTIAL
# {'long_name': 'Potential (i.e., including unresolved) disturbance rate', 'units': 'm2 m-2 d-1', 'cell_methods': 'time: mean'}
# DISTURBANCE_RATE_S2S
# {'long_name': 'Disturbance rate from secondary to secondary lands', 'units': 'm2 m-2 d-1', 'cell_methods': 'time: mean'}
# DISTURBANCE_RATE_TREEFALL
# {'long_name': 'Disturbance rate from treefall', 'units': 'm2 m-2 d-1', 'cell_methods': 'time: mean'}
# DSTDEP
# {'long_name': 'total dust deposition (dry+wet) from atmosphere', 'units': 'kg/m^2/s', 'cell_methods': 'time: mean'}
# DSTFLXT
# {'long_name': 'total surface dust emission', 'units': 'kg/m2/s', 'cell_methods': 'time: mean'}
# DWB
# {'long_name': 'net change in total water mass', 'units': 'mm/s', 'cell_methods': 'time: mean'}
# DWT_CONV_NFLUX_GRC
# {'long_name': 'conversion C flux (immediate loss to atm) (0 at all times except first timestep of year)', 'units': 'gN/m^2/s', 'cell_methods': 'time: mean'}
# DWT_CONV_PFLUX_GRC
# {'long_name': 'conversion C flux (immediate loss to atm) (0 at all times except first timestep of year)', 'units': 'gP/m^2/s', 'cell_methods': 'time: mean'}
# DWT_SLASH_NFLUX
# {'long_name': 'slash N flux to litter and CWD due to land use', 'units': 'gN/m^2/s', 'cell_methods': 'time: mean'}
# DWT_SLASH_PFLUX
# {'long_name': 'slash P flux to litter and CWD due to land use', 'units': 'gP/m^2/s', 'cell_methods': 'time: mean'}
# ED_NCOHORTS
# {'long_name': 'Total number of ED cohorts per site', 'units': 'none', 'cell_methods': 'time: mean'}
# ED_NPATCHES
# {'long_name': 'Total number of ED patches per site', 'units': 'none', 'cell_methods': 'time: mean'}
# ED_balive
# {'long_name': 'Live biomass', 'units': 'gC m-2', 'cell_methods': 'time: mean'}
# ED_bdead
# {'long_name': 'Dead (structural) biomass (live trees, not CWD)', 'units': 'gC m-2', 'cell_methods': 'time: mean'}
# ED_bfineroot
# {'long_name': 'Fine root biomass', 'units': 'gC m-2', 'cell_methods': 'time: mean'}
# ED_biomass
# {'long_name': 'Total biomass', 'units': 'gC m-2', 'cell_methods': 'time: mean'}
# ED_bleaf
# {'long_name': 'Leaf biomass', 'units': 'gC m-2', 'cell_methods': 'time: mean'}
# ED_bsapwood
# {'long_name': 'Sapwood biomass', 'units': 'gC m-2', 'cell_methods': 'time: mean'}
# ED_bstore
# {'long_name': 'Storage biomass', 'units': 'gC m-2', 'cell_methods': 'time: mean'}
# EFFECT_WSPEED
# {'long_name': 'effective windspeed for fire spread', 'units': 'none', 'cell_methods': 'time: mean'}
# EFLX_DYNBAL
# {'long_name': 'dynamic land cover change conversion energy flux', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# EFLX_GRND_LAKE
# {'long_name': 'net heat flux into lake/snow surface, excluding light transmission', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# EFLX_LH_TOT
# {'long_name': 'total latent heat flux [+ to atm]', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# EFLX_LH_TOT_R
# {'long_name': 'Rural total evaporation', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# EFLX_LH_TOT_U
# {'long_name': 'Urban total evaporation', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# ELAI
# {'long_name': 'exposed one-sided leaf area index', 'units': 'm^2/m^2', 'cell_methods': 'time: mean'}
# ERRH2O
# {'long_name': 'total water conservation error', 'units': 'mm', 'cell_methods': 'time: mean'}
# ERRH2OSNO
# {'long_name': 'imbalance in snow depth (liquid water)', 'units': 'mm', 'cell_methods': 'time: mean'}
# ERROR_FATES
# {'long_name': 'total error, FATES mass-balance', 'units': 'mg/day', 'cell_methods': 'time: mean'}
# ERRSEB
# {'long_name': 'surface energy conservation error', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# ERRSOI
# {'long_name': 'soil/lake energy conservation error', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# ERRSOL
# {'long_name': 'solar radiation conservation error', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# ESAI
# {'long_name': 'exposed one-sided stem area index', 'units': 'm^2/m^2', 'cell_methods': 'time: mean'}
# FATES_HR
# {'long_name': 'heterotrophic respiration', 'units': 'gC/m^2/s', 'cell_methods': 'time: mean'}
# FCEV
# {'long_name': 'canopy evaporation', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# FCOV
# {'long_name': 'fractional impermeable area', 'units': 'unitless', 'cell_methods': 'time: mean'}
# FCTR
# {'long_name': 'canopy transpiration', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# FGEV
# {'long_name': 'ground evaporation', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# FGR
# {'long_name': 'heat flux into soil/snow including snow melt and lake / snow light transmission', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# FGR12
# {'long_name': 'heat flux between soil layers 1 and 2', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# FGR_R
# {'long_name': 'Rural heat flux into soil/snow including snow melt and snow light transmission', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# FGR_U
# {'long_name': 'Urban heat flux into soil/snow including snow melt', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# FH2OSFC
# {'long_name': 'fraction of ground covered by surface water', 'units': '1', 'cell_methods': 'time: mean'}
# FIRA
# {'long_name': 'net infrared (longwave) radiation', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# FIRA_R
# {'long_name': 'Rural net infrared (longwave) radiation', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# FIRA_U
# {'long_name': 'Urban net infrared (longwave) radiation', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# FIRE
# {'long_name': 'emitted infrared (longwave) radiation', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# FIRE_AREA
# {'long_name': 'spitfire fire area burn fraction', 'units': 'fraction/day', 'cell_methods': 'time: mean'}
# FIRE_FDI
# {'long_name': 'probability that an ignition will lead to a fire', 'units': 'none', 'cell_methods': 'time: mean'}
# FIRE_FLUX
# {'long_name': 'ED-spitfire loss to atmosphere of elements', 'units': 'g/m^2/s', 'cell_methods': 'time: mean'}
# FIRE_FUEL_BULKD
# {'long_name': 'spitfire fuel bulk density', 'units': 'kg biomass/m3', 'cell_methods': 'time: mean'}
# FIRE_FUEL_EFF_MOIST
# {'long_name': 'spitfire fuel moisture', 'units': 'm', 'cell_methods': 'time: mean'}
# FIRE_FUEL_MEF
# {'long_name': 'spitfire fuel moisture', 'units': 'm', 'cell_methods': 'time: mean'}
# FIRE_FUEL_SAV
# {'long_name': 'spitfire fuel surface/volume', 'units': 'per m', 'cell_methods': 'time: mean'}
# FIRE_IGNITIONS
# {'long_name': 'number of successful ignitions', 'units': 'number/km2/day', 'cell_methods': 'time: mean'}
# FIRE_INTENSITY
# {'long_name': 'spitfire fire intensity: kJ/m/s', 'units': 'kJ/m/s', 'cell_methods': 'time: mean'}
# FIRE_INTENSITY_AREA_PRODUCT
# {'long_name': 'spitfire product of fire intensity and burned area (divide by FIRE_AREA to get area-weighted mean intensity)', 'units': 'kJ/m/s', 'cell_methods': 'time: mean'}
# FIRE_INTENSITY_BY_PATCH_AGE
# {'long_name': 'product of fire intensity and burned area, resolved by patch age (so divide by AREA_BURNT_BY_PATCH_AGE to get burned-area-weight', 'units': 'kJ/m/2', 'cell_methods': 'time: mean'}
# FIRE_NESTEROV_INDEX
# {'long_name': 'nesterov_fire_danger index', 'units': 'none', 'cell_methods': 'time: mean'}
# FIRE_R
# {'long_name': 'Rural emitted infrared (longwave) radiation', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# FIRE_ROS
# {'long_name': 'fire rate of spread m/min', 'units': 'm/min', 'cell_methods': 'time: mean'}
# FIRE_ROS_AREA_PRODUCT
# {'long_name': 'product of fire rate of spread (m/min) and burned area (fraction)--divide by FIRE_AREA to get burned-area-weighted-mean ROS', 'units': 'm/min', 'cell_methods': 'time: mean'}
# FIRE_TFC_ROS
# {'long_name': 'total fuel consumed', 'units': 'kgC/m2', 'cell_methods': 'time: mean'}
# FIRE_TFC_ROS_AREA_PRODUCT
# {'long_name': 'product of total fuel consumed and burned area--divide by FIRE_AREA to get burned-area-weighted-mean TFC', 'units': 'kgC/m2', 'cell_methods': 'time: mean'}
# FIRE_U
# {'long_name': 'Urban emitted infrared (longwave) radiation', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# FLDS
# {'long_name': 'atmospheric longwave radiation', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# FNRTC
# {'long_name': 'Total carbon in live plant fine-roots', 'units': 'kgC ha-1', 'cell_methods': 'time: mean'}
# FPSN
# {'long_name': 'photosynthesis', 'units': 'umol/m2s', 'cell_methods': 'time: mean'}
# FPSN_WC
# {'long_name': 'Rubisco-limited photosynthesis', 'units': 'umol/m2s', 'cell_methods': 'time: mean'}
# FPSN_WJ
# {'long_name': 'RuBP-limited photosynthesis', 'units': 'umol/m2s', 'cell_methods': 'time: mean'}
# FPSN_WP
# {'long_name': 'Product-limited photosynthesis', 'units': 'umol/m2s', 'cell_methods': 'time: mean'}
# FRAGMENTATION_SCALER_SL
# {'long_name': 'factor by which litter/cwd fragmentation proceeds relative to max rate by soil layer', 'units': 'unitless (0-1)', 'cell_methods': 'time: mean'}
# FROOT_MR
# {'long_name': 'fine root maintenance respiration)', 'units': 'kg C / m2 / yr', 'cell_methods': 'time: mean'}
# FROST_TABLE
# {'long_name': 'frost table depth (vegetated landunits only)', 'units': 'm', 'cell_methods': 'time: mean'}
# FSA
# {'long_name': 'absorbed solar radiation', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# FSAT
# {'long_name': 'fractional area with water table at surface', 'units': 'unitless', 'cell_methods': 'time: mean'}
# FSA_R
# {'long_name': 'Rural absorbed solar radiation', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# FSA_U
# {'long_name': 'Urban absorbed solar radiation', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# FSDS
# {'long_name': 'atmospheric incident solar radiation', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# FSDSND
# {'long_name': 'direct nir incident solar radiation', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# FSDSNDLN
# {'long_name': 'direct nir incident solar radiation at local noon', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# FSDSNI
# {'long_name': 'diffuse nir incident solar radiation', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# FSDSVD
# {'long_name': 'direct vis incident solar radiation', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# FSDSVDLN
# {'long_name': 'direct vis incident solar radiation at local noon', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# FSDSVI
# {'long_name': 'diffuse vis incident solar radiation', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# FSDSVILN
# {'long_name': 'diffuse vis incident solar radiation at local noon', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# FSH
# {'long_name': 'sensible heat', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# FSH_G
# {'long_name': 'sensible heat from ground', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# FSH_NODYNLNDUSE
# {'long_name': 'sensible heat not including correction for land use change', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# FSH_R
# {'long_name': 'Rural sensible heat', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# FSH_U
# {'long_name': 'Urban sensible heat', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# FSH_V
# {'long_name': 'sensible heat from veg', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# FSM
# {'long_name': 'snow melt heat flux', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# FSM_R
# {'long_name': 'Rural snow melt heat flux', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# FSM_U
# {'long_name': 'Urban snow melt heat flux', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# FSNO
# {'long_name': 'fraction of ground covered by snow', 'units': '1', 'cell_methods': 'time: mean'}
# FSNO_EFF
# {'long_name': 'effective fraction of ground covered by snow', 'units': '1', 'cell_methods': 'time: mean'}
# FSR
# {'long_name': 'reflected solar radiation', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# FSRND
# {'long_name': 'direct nir reflected solar radiation', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# FSRNDLN
# {'long_name': 'direct nir reflected solar radiation at local noon', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# FSRNI
# {'long_name': 'diffuse nir reflected solar radiation', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# FSRVD
# {'long_name': 'direct vis reflected solar radiation', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# FSRVDLN
# {'long_name': 'direct vis reflected solar radiation at local noon', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# FSRVI
# {'long_name': 'diffuse vis reflected solar radiation', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# FUEL_AMOUNT_AGEFUEL
# {'long_name': 'spitfire fuel quantity in each age x fuel class', 'units': 'kg C / m2', 'cell_methods': 'time: mean'}
# FUEL_AMOUNT_BY_NFSC
# {'long_name': 'spitfire size-resolved fuel quantity', 'units': 'kg C / m2', 'cell_methods': 'time: mean'}
# FUEL_MOISTURE_NFSC
# {'long_name': 'spitfire size-resolved fuel moisture', 'units': '-', 'cell_methods': 'time: mean'}
# F_DENIT
# {'long_name': 'denitrification flux', 'units': 'gN/m^2/s', 'cell_methods': 'time: mean'}
# F_DENIT_vr
# {'long_name': 'denitrification flux', 'units': 'gN/m^3/s', 'cell_methods': 'time: mean'}
# F_N2O_DENIT
# {'long_name': 'denitrification N2O flux', 'units': 'gN/m^2/s', 'cell_methods': 'time: mean'}
# F_N2O_NIT
# {'long_name': 'nitrification N2O flux', 'units': 'gN/m^2/s', 'cell_methods': 'time: mean'}
# F_NIT
# {'long_name': 'nitrification flux', 'units': 'gN/m^2/s', 'cell_methods': 'time: mean'}
# F_NIT_vr
# {'long_name': 'nitrification flux', 'units': 'gN/m^3/s', 'cell_methods': 'time: mean'}
# Fire_Closs
# {'long_name': 'ED/SPitfire Carbon loss to atmosphere', 'units': 'gC/m^2/s', 'cell_methods': 'time: mean'}
# GC_HEAT1
# {'long_name': 'initial gridcell total heat content', 'units': 'J/m^2', 'cell_methods': 'time: mean'}
# GC_ICE1
# {'long_name': 'initial gridcell total ice content', 'units': 'mm', 'cell_methods': 'time: mean'}
# GC_LIQ1
# {'long_name': 'initial gridcell total liq content', 'units': 'mm', 'cell_methods': 'time: mean'}
# GPP
# {'long_name': 'gross primary production', 'units': 'gC/m^2/s', 'cell_methods': 'time: mean'}
# GPP_CANOPY
# {'long_name': 'gross primary production of canopy plants', 'units': 'gC/m^2/s', 'cell_methods': 'time: mean'}
# GPP_UNDERSTORY
# {'long_name': 'gross primary production of understory plants', 'units': 'gC/m^2/s', 'cell_methods': 'time: mean'}
# GROSS_NMIN
# {'long_name': 'gross rate of N mineralization', 'units': 'gN/m^2/s', 'cell_methods': 'time: mean'}
# GROSS_PMIN
# {'long_name': 'gross rate of P mineralization', 'units': 'gP/m^2/s', 'cell_methods': 'time: mean'}
# GROWTH_RESP
# {'long_name': 'growth respiration', 'units': 'gC/m^2/s', 'cell_methods': 'time: mean'}
# H2OCAN
# {'long_name': 'intercepted water', 'units': 'mm', 'cell_methods': 'time: mean'}
# H2OSFC
# {'long_name': 'surface water depth', 'units': 'mm', 'cell_methods': 'time: mean'}
# H2OSNO
# {'long_name': 'snow depth (liquid water)', 'units': 'mm', 'cell_methods': 'time: mean'}
# H2OSNO_TOP
# {'long_name': 'mass of snow in top snow layer', 'units': 'kg/m2', 'cell_methods': 'time: mean'}
# H2OSOI
# {'long_name': 'volumetric soil water (vegetated landunits only)', 'units': 'mm3/mm3', 'cell_methods': 'time: mean'}
# HARVEST_CARBON_FLUX
# {'long_name': 'Harvest carbon flux', 'units': 'kg C m-2 d-1', 'cell_methods': 'time: mean'}
# HC
# {'long_name': 'heat content of soil/snow/lake', 'units': 'MJ/m2', 'cell_methods': 'time: mean'}
# HCSOI
# {'long_name': 'soil heat content', 'units': 'MJ/m2', 'cell_methods': 'time: mean'}
# HEAT_FROM_AC
# {'long_name': 'sensible heat flux put into canyon due to heat removed from air conditioning', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# HR
# {'long_name': 'total heterotrophic respiration', 'units': 'gC/m^2/s', 'cell_methods': 'time: mean'}
# HR_vr
# {'long_name': 'total vertically resolved heterotrophic respiration', 'units': 'gC/m^3/s', 'cell_methods': 'time: mean'}
# HTOP
# {'long_name': 'canopy top', 'units': 'm', 'cell_methods': 'time: mean'}
# INT_SNOW
# {'long_name': 'accumulated swe (vegetated landunits only)', 'units': 'mm', 'cell_methods': 'time: mean'}
# LABILEP
# {'long_name': 'soil Labile P', 'units': 'gP/m^2', 'cell_methods': 'time: mean'}
# LABILEP_TO_SECONDP
# {'long_name': 'LABILE P TO SECONDARY MINERAL P', 'units': 'gP/m^2/s', 'cell_methods': 'time: mean'}
# LABILEP_vr
# {'long_name': 'soil labile P (vert. res.)', 'units': 'gp/m^3', 'cell_methods': 'time: mean'}
# LAISHA
# {'long_name': 'shaded projected leaf area index', 'units': '1', 'cell_methods': 'time: mean'}
# LAISUN
# {'long_name': 'sunlit projected leaf area index', 'units': '1', 'cell_methods': 'time: mean'}
# LAI_BY_AGE
# {'long_name': 'leaf area index by age bin', 'units': 'm2/m2', 'cell_methods': 'time: mean'}
# LAI_CANOPY_SCLS
# {'long_name': 'Leaf are index (LAI) by size class', 'units': 'm2/m2', 'cell_methods': 'time: mean'}
# LAI_UNDERSTORY_SCLS
# {'long_name': 'number of understory plants by size class', 'units': 'indiv/ha', 'cell_methods': 'time: mean'}
# LAKEICEFRAC
# {'long_name': 'lake layer ice mass fraction', 'units': 'unitless', 'cell_methods': 'time: mean'}
# LAKEICETHICK
# {'long_name': 'thickness of lake ice (including physical expansion on freezing)', 'units': 'm', 'cell_methods': 'time: mean'}
# LEAFC
# {'long_name': 'Total carbon in live plant leaves', 'units': 'kgC ha-1', 'cell_methods': 'time: mean'}
# LEAF_HEIGHT_DIST
# {'long_name': 'leaf height distribution', 'units': 'm2/m2', 'cell_methods': 'time: mean'}
# LEAF_MR
# {'long_name': 'RDARK (leaf maintenance respiration)', 'units': 'kg C / m2 / yr', 'cell_methods': 'time: mean'}
# LITHR
# {'long_name': 'litter heterotrophic respiration', 'units': 'gC/m^2/s', 'cell_methods': 'time: mean'}
# LITR1C
# {'long_name': 'LITR1 C', 'units': 'gC/m^2', 'cell_methods': 'time: mean'}
# LITR1C_vr
# {'long_name': 'LITR1 C (vertically resolved)', 'units': 'gC/m^3', 'cell_methods': 'time: mean'}
# LITR1N
# {'long_name': 'LITR1 N', 'units': 'gN/m^2', 'cell_methods': 'time: mean'}
# LITR1N_TNDNCY_VERT_TRANS
# {'long_name': 'litter 1 N tendency due to vertical transport', 'units': 'gN/m^3/s', 'cell_methods': 'time: mean'}
# LITR1N_TO_SOIL1N
# {'long_name': 'decomp. of litter 1 N to soil 1 N', 'units': 'gN/m^2', 'cell_methods': 'time: mean'}
# LITR1N_vr
# {'long_name': 'LITR1 N (vertically resolved)', 'units': 'gN/m^3', 'cell_methods': 'time: mean'}
# LITR1P
# {'long_name': 'LITR1 P', 'units': 'gP/m^2', 'cell_methods': 'time: mean'}
# LITR1P_TNDNCY_VERT_TRANS
# {'long_name': 'litter 1 P tendency due to vertical transport', 'units': 'gP/m^3/s', 'cell_methods': 'time: mean'}
# LITR1P_TO_SOIL1P
# {'long_name': 'decomp. of litter 1 P to soil 1 N', 'units': 'gP/m^2', 'cell_methods': 'time: mean'}
# LITR1P_vr
# {'long_name': 'LITR1 P (vertically resolved)', 'units': 'gP/m^3', 'cell_methods': 'time: mean'}
# LITR2C
# {'long_name': 'LITR2 C', 'units': 'gC/m^2', 'cell_methods': 'time: mean'}
# LITR2C_vr
# {'long_name': 'LITR2 C (vertically resolved)', 'units': 'gC/m^3', 'cell_methods': 'time: mean'}
# LITR2N
# {'long_name': 'LITR2 N', 'units': 'gN/m^2', 'cell_methods': 'time: mean'}
# LITR2N_TNDNCY_VERT_TRANS
# {'long_name': 'litter 2 N tendency due to vertical transport', 'units': 'gN/m^3/s', 'cell_methods': 'time: mean'}
# LITR2N_TO_SOIL2N
# {'long_name': 'decomp. of litter 2 N to soil 2 N', 'units': 'gN/m^2', 'cell_methods': 'time: mean'}
# LITR2N_vr
# {'long_name': 'LITR2 N (vertically resolved)', 'units': 'gN/m^3', 'cell_methods': 'time: mean'}
# LITR2P
# {'long_name': 'LITR2 P', 'units': 'gP/m^2', 'cell_methods': 'time: mean'}
# LITR2P_TNDNCY_VERT_TRANS
# {'long_name': 'litter 2 P tendency due to vertical transport', 'units': 'gP/m^3/s', 'cell_methods': 'time: mean'}
# LITR2P_TO_SOIL2P
# {'long_name': 'decomp. of litter 2 P to soil 2 N', 'units': 'gP/m^2', 'cell_methods': 'time: mean'}
# LITR2P_vr
# {'long_name': 'LITR2 P (vertically resolved)', 'units': 'gP/m^3', 'cell_methods': 'time: mean'}
# LITR3C
# {'long_name': 'LITR3 C', 'units': 'gC/m^2', 'cell_methods': 'time: mean'}
# LITR3C_vr
# {'long_name': 'LITR3 C (vertically resolved)', 'units': 'gC/m^3', 'cell_methods': 'time: mean'}
# LITR3N
# {'long_name': 'LITR3 N', 'units': 'gN/m^2', 'cell_methods': 'time: mean'}
# LITR3N_TNDNCY_VERT_TRANS
# {'long_name': 'litter 3 N tendency due to vertical transport', 'units': 'gN/m^3/s', 'cell_methods': 'time: mean'}
# LITR3N_TO_SOIL3N
# {'long_name': 'decomp. of litter 3 N to soil 3 N', 'units': 'gN/m^2', 'cell_methods': 'time: mean'}
# LITR3N_vr
# {'long_name': 'LITR3 N (vertically resolved)', 'units': 'gN/m^3', 'cell_methods': 'time: mean'}
# LITR3P
# {'long_name': 'LITR3 P', 'units': 'gP/m^2', 'cell_methods': 'time: mean'}
# LITR3P_TNDNCY_VERT_TRANS
# {'long_name': 'litter 3 P tendency due to vertical transport', 'units': 'gP/m^3/s', 'cell_methods': 'time: mean'}
# LITR3P_TO_SOIL3P
# {'long_name': 'decomp. of litter 3 P to soil 3 N', 'units': 'gP/m^2', 'cell_methods': 'time: mean'}
# LITR3P_vr
# {'long_name': 'LITR3 P (vertically resolved)', 'units': 'gP/m^3', 'cell_methods': 'time: mean'}
# LITTERC
# {'long_name': 'litter C', 'units': 'gC/m^2', 'cell_methods': 'time: mean'}
# LITTER_CWD
# {'long_name': 'total mass of litter in CWD', 'units': 'kg ha-1', 'cell_methods': 'time: mean'}
# LITTER_CWD_AG_ELEM
# {'long_name': 'mass of above ground litter in CWD (trunks/branches/twigs)', 'units': 'kg ha-1', 'cell_methods': 'time: mean'}
# LITTER_CWD_BG_ELEM
# {'long_name': 'mass of below ground litter in CWD (coarse roots)', 'units': 'kg ha-1', 'cell_methods': 'time: mean'}
# LITTER_FINES_AG_ELEM
# {'long_name': 'mass of above ground  litter in fines (leaves,nonviable seed)', 'units': 'kg ha-1', 'cell_methods': 'time: mean'}
# LITTER_FINES_BG_ELEM
# {'long_name': 'mass of below ground litter in fines (fineroots)', 'units': 'kg ha-1', 'cell_methods': 'time: mean'}
# LITTER_IN
# {'long_name': 'FATES litter flux in', 'units': 'gC m-2 s-1', 'cell_methods': 'time: mean'}
# LITTER_IN_ELEM
# {'long_name': 'FATES litter flux in', 'units': 'kg ha-1 d-1', 'cell_methods': 'time: mean'}
# LITTER_OUT
# {'long_name': 'FATES litter flux out', 'units': 'gC m-2 s-1', 'cell_methods': 'time: mean'}
# LITTER_OUT_ELEM
# {'long_name': 'FATES litter flux out (fragmentation only)', 'units': 'kg ha-1 d-1', 'cell_methods': 'time: mean'}
# LIVECROOT_MR
# {'long_name': 'live coarse root maintenance respiration)', 'units': 'kg C / m2 / yr', 'cell_methods': 'time: mean'}
# LIVESTEM_MR
# {'long_name': 'live stem maintenance respiration)', 'units': 'kg C / m2 / yr', 'cell_methods': 'time: mean'}
# M10_CACLS
# {'long_name': 'age senescence mortality by cohort age', 'units': 'N/ha/yr', 'cell_methods': 'time: mean'}
# M10_SCLS
# {'long_name': 'age senescence mortality by size', 'units': 'N/ha/yr', 'cell_methods': 'time: mean'}
# M1_SCLS
# {'long_name': 'background mortality by size', 'units': 'N/ha/yr', 'cell_methods': 'time: mean'}
# M2_SCLS
# {'long_name': 'hydraulic mortality by size', 'units': 'N/ha/yr', 'cell_methods': 'time: mean'}
# M3_SCLS
# {'long_name': 'carbon starvation mortality by size', 'units': 'N/ha/yr', 'cell_methods': 'time: mean'}
# M4_SCLS
# {'long_name': 'impact mortality by size', 'units': 'N/ha/yr', 'cell_methods': 'time: mean'}
# M5_SCLS
# {'long_name': 'fire mortality by size', 'units': 'N/ha/yr', 'cell_methods': 'time: mean'}
# M6_SCLS
# {'long_name': 'termination mortality by size', 'units': 'N/ha/yr', 'cell_methods': 'time: mean'}
# M7_SCLS
# {'long_name': 'logging mortality by size', 'units': 'N/ha/event', 'cell_methods': 'time: mean'}
# M8_SCLS
# {'long_name': 'freezing mortality by size', 'units': 'N/ha/event', 'cell_methods': 'time: mean'}
# M9_SCLS
# {'long_name': 'senescence mortality by size', 'units': 'N/ha/yr', 'cell_methods': 'time: mean'}
# MAINT_RESP
# {'long_name': 'maintenance respiration', 'units': 'gC/m^2/s', 'cell_methods': 'time: mean'}
# MORTALITY
# {'long_name': 'Rate of total mortality by PFT', 'units': 'indiv/ha/yr', 'cell_methods': 'time: mean'}
# MORTALITY_CANOPY_SCLS
# {'long_name': 'total mortality of canopy trees by size class', 'units': 'indiv/ha/yr', 'cell_methods': 'time: mean'}
# MORTALITY_CARBONFLUX_CANOPY
# {'long_name': 'flux of biomass carbon from live to dead pools from mortality of canopy plants', 'units': 'gC/m2/s', 'cell_methods': 'time: mean'}
# MORTALITY_CARBONFLUX_UNDERSTORY
# {'long_name': 'flux of biomass carbon from live to dead pools from mortality of understory plants', 'units': 'gC/m2/s', 'cell_methods': 'time: mean'}
# MORTALITY_UNDERSTORY_SCLS
# {'long_name': 'total mortality of understory trees by size class', 'units': 'indiv/ha/yr', 'cell_methods': 'time: mean'}
# NDEP_TO_SMINN
# {'long_name': 'atmospheric N deposition to soil mineral N', 'units': 'gN/m^2/s', 'cell_methods': 'time: mean'}
# NEP
# {'long_name': 'net ecosystem production', 'units': 'gC/m^2/s', 'cell_methods': 'time: mean'}
# NET_NMIN
# {'long_name': 'net rate of N mineralization', 'units': 'gN/m^2/s', 'cell_methods': 'time: mean'}
# NET_PMIN
# {'long_name': 'net rate of P mineralization', 'units': 'gP/m^2/s', 'cell_methods': 'time: mean'}
# NFIX_TO_SMINN
# {'long_name': 'symbiotic/asymbiotic N fixation to soil mineral N', 'units': 'gN/m^2/s', 'cell_methods': 'time: mean'}
# NPLANT_CACLS
# {'long_name': 'number of plants by coage class', 'units': 'indiv/ha', 'cell_methods': 'time: mean'}
# NPLANT_CANOPY_SCLS
# {'long_name': 'number of canopy plants by size class', 'units': 'indiv/ha', 'cell_methods': 'time: mean'}
# NPLANT_SCAG
# {'long_name': 'number of plants per hectare in each size x age class', 'units': 'plants/ha', 'cell_methods': 'time: mean'}
# NPLANT_SCLS
# {'long_name': 'number of plants by size class', 'units': 'indiv/ha', 'cell_methods': 'time: mean'}
# NPLANT_UNDERSTORY_SCLS
# {'long_name': 'number of understory plants by size class', 'units': 'indiv/ha', 'cell_methods': 'time: mean'}
# NPP
# {'long_name': 'net primary production', 'units': 'gC/m^2/s', 'cell_methods': 'time: mean'}
# NPP_CROOT
# {'long_name': 'NPP flux into coarse roots', 'units': 'kgC/m2/yr', 'cell_methods': 'time: mean'}
# NPP_FROOT
# {'long_name': 'NPP flux into fine roots', 'units': 'kgC/m2/yr', 'cell_methods': 'time: mean'}
# NPP_LEAF
# {'long_name': 'NPP flux into leaves', 'units': 'kgC/m2/yr', 'cell_methods': 'time: mean'}
# NPP_SEED
# {'long_name': 'NPP flux into seeds', 'units': 'kgC/m2/yr', 'cell_methods': 'time: mean'}
# NPP_STEM
# {'long_name': 'NPP flux into stem', 'units': 'kgC/m2/yr', 'cell_methods': 'time: mean'}
# NPP_STOR
# {'long_name': 'NPP flux into storage tissues', 'units': 'kgC/m2/yr', 'cell_methods': 'time: mean'}
# OCCLP
# {'long_name': 'soil occluded P', 'units': 'gP/m^2', 'cell_methods': 'time: mean'}
# OCCLP_vr
# {'long_name': 'soil occluded P (vert. res.)', 'units': 'gp/m^3', 'cell_methods': 'time: mean'}
# OCDEP
# {'long_name': 'total OC deposition (dry+wet) from atmosphere', 'units': 'kg/m^2/s', 'cell_methods': 'time: mean'}
# PARVEGLN
# {'long_name': 'absorbed par by vegetation at local noon', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# PATCH_AREA_BY_AGE
# {'long_name': 'patch area by age bin', 'units': 'm2/m2', 'cell_methods': 'time: mean'}
# PBOT
# {'long_name': 'atmospheric pressure', 'units': 'Pa', 'cell_methods': 'time: mean'}
# PCO2
# {'long_name': 'atmospheric partial pressure of CO2', 'units': 'Pa', 'cell_methods': 'time: mean'}
# PCT_LANDUNIT
# {'long_name': '% of each landunit on topounit', 'units': '%', 'cell_methods': 'time: mean'}
# PCT_NAT_PFT
# {'long_name': '% of each PFT on the natural vegetation (i.e., soil) landunit', 'units': '%', 'cell_methods': 'time: mean'}
# PDEP_TO_SMINP
# {'long_name': 'atmospheric P deposition to soil mineral P', 'units': 'gP/m^2/s', 'cell_methods': 'time: mean'}
# PFTbiomass
# {'long_name': 'total PFT level biomass', 'units': 'gC/m2', 'cell_methods': 'time: mean'}
# PFTgpp
# {'long_name': 'total PFT-level GPP', 'units': 'kg C m-2 y-1', 'cell_methods': 'time: mean'}
# PFTleafbiomass
# {'long_name': 'total PFT level leaf biomass', 'units': 'gC/m2', 'cell_methods': 'time: mean'}
# PFTnindivs
# {'long_name': 'total PFT level number of individuals', 'units': 'indiv / m2', 'cell_methods': 'time: mean'}
# PFTnpp
# {'long_name': 'total PFT-level NPP', 'units': 'kg C m-2 y-1', 'cell_methods': 'time: mean'}
# PFTstorebiomass
# {'long_name': 'total PFT level stored biomass', 'units': 'gC/m2', 'cell_methods': 'time: mean'}
# PLANT_NDEMAND_COL
# {'long_name': 'N flux required to support initial GPP', 'units': 'gN/m^2/s', 'cell_methods': 'time: mean'}
# PLANT_PDEMAND_COL
# {'long_name': 'P flux required to support initial GPP', 'units': 'gN/m^2/s', 'cell_methods': 'time: mean'}
# POTENTIAL_IMMOB
# {'long_name': 'potential N immobilization', 'units': 'gN/m^2/s', 'cell_methods': 'time: mean'}
# POTENTIAL_IMMOB_P
# {'long_name': 'potential P immobilization', 'units': 'gP/m^2/s', 'cell_methods': 'time: mean'}
# POT_F_DENIT
# {'long_name': 'potential denitrification flux', 'units': 'gN/m^2/s', 'cell_methods': 'time: mean'}
# POT_F_NIT
# {'long_name': 'potential nitrification flux', 'units': 'gN/m^2/s', 'cell_methods': 'time: mean'}
# PRIMARYLAND_PATCHFUSION_ERROR
# {'long_name': 'Error in total primary lands associated with patch fusion', 'units': 'm2 m-2 d-1', 'cell_methods': 'time: mean'}
# PRIMP
# {'long_name': 'soil primary P', 'units': 'gP/m^2', 'cell_methods': 'time: mean'}
# PRIMP_TO_LABILEP
# {'long_name': 'PRIMARY MINERAL P TO LABILE P', 'units': 'gP/m^2/s', 'cell_methods': 'time: mean'}
# PRIMP_vr
# {'long_name': 'soil primary P (vert. res.)', 'units': 'gp/m^3', 'cell_methods': 'time: mean'}
# PROD1P_LOSS
# {'long_name': 'loss from 1-yr crop product pool', 'units': 'gP/m^2/s', 'cell_methods': 'time: mean'}
# PROMOTION_CARBONFLUX
# {'long_name': 'promotion-associated biomass carbon flux from understory to canopy', 'units': 'gC/m2/s', 'cell_methods': 'time: mean'}
# Q2M
# {'long_name': '2m specific humidity', 'units': 'kg/kg', 'cell_methods': 'time: mean'}
# QBOT
# {'long_name': 'atmospheric specific humidity', 'units': 'kg/kg', 'cell_methods': 'time: mean'}
# QCHARGE
# {'long_name': 'aquifer recharge rate (vegetated landunits only)', 'units': 'mm/s', 'cell_methods': 'time: mean'}
# QDRAI
# {'long_name': 'sub-surface drainage', 'units': 'mm/s', 'cell_methods': 'time: mean'}
# QDRAI_PERCH
# {'long_name': 'perched wt drainage', 'units': 'mm/s', 'cell_methods': 'time: mean'}
# QDRAI_XS
# {'long_name': 'saturation excess drainage', 'units': 'mm/s', 'cell_methods': 'time: mean'}
# QDRIP
# {'long_name': 'throughfall', 'units': 'mm/s', 'cell_methods': 'time: mean'}
# QFLOOD
# {'long_name': 'runoff from river flooding', 'units': 'mm/s', 'cell_methods': 'time: mean'}
# QFLX_ICE_DYNBAL
# {'long_name': 'ice dynamic land cover change conversion runoff flux', 'units': 'mm/s', 'cell_methods': 'time: mean'}
# QFLX_LIQ_DYNBAL
# {'long_name': 'liq dynamic land cover change conversion runoff flux', 'units': 'mm/s', 'cell_methods': 'time: mean'}
# QH2OSFC
# {'long_name': 'surface water runoff', 'units': 'mm/s', 'cell_methods': 'time: mean'}
# QINFL
# {'long_name': 'infiltration', 'units': 'mm/s', 'cell_methods': 'time: mean'}
# QINTR
# {'long_name': 'interception', 'units': 'mm/s', 'cell_methods': 'time: mean'}
# QIRRIG_GRND
# {'long_name': 'Groundwater irrigation', 'units': 'mm/s', 'cell_methods': 'time: mean'}
# QIRRIG_ORIG
# {'long_name': 'Original total irrigation water demand (surface + ground)', 'units': 'mm/s', 'cell_methods': 'time: mean'}
# QIRRIG_REAL
# {'long_name': 'actual water added through irrigation (surface + ground)', 'units': 'mm/s', 'cell_methods': 'time: mean'}
# QIRRIG_SURF
# {'long_name': 'Surface water irrigation', 'units': 'mm/s', 'cell_methods': 'time: mean'}
# QIRRIG_WM
# {'long_name': 'Surface water irrigation demand sent to MOSART/WM', 'units': 'mm/s', 'cell_methods': 'time: mean'}
# QOVER
# {'long_name': 'surface runoff', 'units': 'mm/s', 'cell_methods': 'time: mean'}
# QRGWL
# {'long_name': 'surface runoff at glaciers (liquid only), wetlands, lakes', 'units': 'mm/s', 'cell_methods': 'time: mean'}
# QRUNOFF
# {'long_name': 'total liquid runoff (does not include QSNWCPICE)', 'units': 'mm/s', 'cell_methods': 'time: mean'}
# QRUNOFF_NODYNLNDUSE
# {'long_name': 'total liquid runoff (does not include QSNWCPICE) not including correction for land use change', 'units': 'mm/s', 'cell_methods': 'time: mean'}
# QRUNOFF_R
# {'long_name': 'Rural total runoff', 'units': 'mm/s', 'cell_methods': 'time: mean'}
# QRUNOFF_U
# {'long_name': 'Urban total runoff', 'units': 'mm/s', 'cell_methods': 'time: mean'}
# QSNOMELT
# {'long_name': 'snow melt', 'units': 'mm/s', 'cell_methods': 'time: mean'}
# QSNWCPICE
# {'long_name': 'excess snowfall due to snow capping', 'units': 'mm/s', 'cell_methods': 'time: mean'}
# QSNWCPICE_NODYNLNDUSE
# {'long_name': 'excess snowfall due to snow capping not including correction for land use change', 'units': 'mm H2O/s', 'cell_methods': 'time: mean'}
# QSOIL
# {'long_name': 'Ground evaporation (soil/snow evaporation + soil/snow sublimation - dew)', 'units': 'mm/s', 'cell_methods': 'time: mean'}
# QVEGE
# {'long_name': 'canopy evaporation', 'units': 'mm/s', 'cell_methods': 'time: mean'}
# QVEGT
# {'long_name': 'canopy transpiration', 'units': 'mm/s', 'cell_methods': 'time: mean'}
# RAIN
# {'long_name': 'atmospheric rain', 'units': 'mm/s', 'cell_methods': 'time: mean'}
# RECRUITMENT
# {'long_name': 'Rate of recruitment by PFT', 'units': 'indiv/ha/yr', 'cell_methods': 'time: mean'}
# REPROC
# {'long_name': 'Total carbon in live plant reproductive tissues', 'units': 'kgC ha-1', 'cell_methods': 'time: mean'}
# RH2M
# {'long_name': '2m relative humidity', 'units': '%', 'cell_methods': 'time: mean'}
# RH2M_R
# {'long_name': 'Rural 2m specific humidity', 'units': '%', 'cell_methods': 'time: mean'}
# RH2M_U
# {'long_name': 'Urban 2m relative humidity', 'units': '%', 'cell_methods': 'time: mean'}
# SABG
# {'long_name': 'solar rad absorbed by ground', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# SABG_PEN
# {'long_name': 'Rural solar rad penetrating top soil or snow layer', 'units': 'watt/m^2', 'cell_methods': 'time: mean'}
# SABV
# {'long_name': 'solar rad absorbed by veg', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# SAPWC
# {'long_name': 'Total carbon in live plant sapwood', 'units': 'kgC ha-1', 'cell_methods': 'time: mean'}
# SCORCH_HEIGHT
# {'long_name': 'SPITFIRE Flame Scorch Height (calculated per PFT in each patch age bin)', 'units': 'm', 'cell_methods': 'time: mean'}
# SECONDP
# {'long_name': 'soil secondary P', 'units': 'gP/m^2', 'cell_methods': 'time: mean'}
# SECONDP_TO_LABILEP
# {'long_name': 'SECONDARY MINERAL P TO LABILE P', 'units': 'gP/m^2/s', 'cell_methods': 'time: mean'}
# SECONDP_TO_OCCLP
# {'long_name': 'SECONDARY MINERAL P TO OCCLUDED P', 'units': 'gP/m^2/s', 'cell_methods': 'time: mean'}
# SECONDP_vr
# {'long_name': 'soil secondary P (vert. res.)', 'units': 'gp/m^3', 'cell_methods': 'time: mean'}
# SEEDS_IN
# {'long_name': 'Seed Production Rate', 'units': 'gC m-2 s-1', 'cell_methods': 'time: mean'}
# SEEDS_IN_EXTERN_ELEM
# {'long_name': 'External Seed Influx Rate', 'units': 'kg ha-1 d-1', 'cell_methods': 'time: mean'}
# SEEDS_IN_LOCAL_ELEM
# {'long_name': 'Within Site Seed Production Rate', 'units': 'kg ha-1 d-1', 'cell_methods': 'time: mean'}
# SEED_BANK
# {'long_name': 'Total Seed Mass of all PFTs', 'units': 'gC m-2', 'cell_methods': 'time: mean'}
# SEED_BANK_ELEM
# {'long_name': 'Total Seed Mass of all PFTs', 'units': 'kg ha-1', 'cell_methods': 'time: mean'}
# SEED_DECAY_ELEM
# {'long_name': 'Seed mass decay (germinated and un-germinated)', 'units': 'kg ha-1 d-1', 'cell_methods': 'time: mean'}
# SEED_GERM_ELEM
# {'long_name': 'Seed mass converted into new cohorts', 'units': 'kg ha-1 d-1', 'cell_methods': 'time: mean'}
# SITE_COLD_STATUS
# {'long_name': 'Site level cold status, 0=not cold-dec, 1=too cold for leaves, 2=not-too cold', 'units': '0,1,2', 'cell_methods': 'time: mean'}
# SITE_DAYSINCE_COLDLEAFOFF
# {'long_name': 'site level days elapsed since cold leaf drop', 'cell_methods': 'time: mean'}
# SITE_DAYSINCE_COLDLEAFON
# {'long_name': 'site level days elapsed since cold leaf flush', 'cell_methods': 'time: mean'}
# SITE_DAYSINCE_DROUGHTLEAFOFF
# {'long_name': 'site level days elapsed since drought leaf drop', 'cell_methods': 'time: mean'}
# SITE_DAYSINCE_DROUGHTLEAFON
# {'long_name': 'site level days elapsed since drought leaf flush', 'cell_methods': 'time: mean'}
# SITE_DROUGHT_STATUS
# {'long_name': 'Site level drought status, <2 too dry for leaves, >=2 not-too dry', 'units': '0,1,2,3', 'cell_methods': 'time: mean'}
# SITE_GDD
# {'long_name': 'site level growing degree days', 'units': 'degC', 'cell_methods': 'time: mean'}
# SITE_MEANLIQVOL_DROUGHTPHEN
# {'long_name': 'site level mean liquid water volume for drought phen', 'units': 'm3/m3', 'cell_methods': 'time: mean'}
# SITE_NCHILLDAYS
# {'long_name': 'site level number of chill days', 'cell_methods': 'time: mean'}
# SITE_NCOLDDAYS
# {'long_name': 'site level number of cold days', 'cell_methods': 'time: mean'}
# SMINN
# {'long_name': 'soil mineral N', 'units': 'gN/m^2', 'cell_methods': 'time: mean'}
# SMINN_TO_PLANT
# {'long_name': 'plant uptake of soil mineral N', 'units': 'gN/m^2/s', 'cell_methods': 'time: mean'}
# SMINN_TO_SOIL1N_L1
# {'long_name': 'mineral N flux for decomp. of LITR1to SOIL1', 'units': 'gN/m^2', 'cell_methods': 'time: mean'}
# SMINN_TO_SOIL2N_L2
# {'long_name': 'mineral N flux for decomp. of LITR2to SOIL2', 'units': 'gN/m^2', 'cell_methods': 'time: mean'}
# SMINN_TO_SOIL2N_S1
# {'long_name': 'mineral N flux for decomp. of SOIL1to SOIL2', 'units': 'gN/m^2', 'cell_methods': 'time: mean'}
# SMINN_TO_SOIL3N_L3
# {'long_name': 'mineral N flux for decomp. of LITR3to SOIL3', 'units': 'gN/m^2', 'cell_methods': 'time: mean'}
# SMINN_TO_SOIL3N_S2
# {'long_name': 'mineral N flux for decomp. of SOIL2to SOIL3', 'units': 'gN/m^2', 'cell_methods': 'time: mean'}
# SMINN_TO_SOIL4N_S3
# {'long_name': 'mineral N flux for decomp. of SOIL3to SOIL4', 'units': 'gN/m^2', 'cell_methods': 'time: mean'}
# SMINP
# {'long_name': 'soil mineral P', 'units': 'gP/m^2', 'cell_methods': 'time: mean'}
# SMINP_LEACHED
# {'long_name': 'soil mineral P pool loss to leaching', 'units': 'gP/m^2/s', 'cell_methods': 'time: mean'}
# SMINP_TO_PLANT
# {'long_name': 'plant uptake of soil mineral P', 'units': 'gP/m^2/s', 'cell_methods': 'time: mean'}
# SMINP_TO_SOIL1P_L1
# {'long_name': 'mineral P flux for decomp. of LITR1to SOIL1', 'units': 'gP/m^2', 'cell_methods': 'time: mean'}
# SMINP_TO_SOIL2P_L2
# {'long_name': 'mineral P flux for decomp. of LITR2to SOIL2', 'units': 'gP/m^2', 'cell_methods': 'time: mean'}
# SMINP_TO_SOIL2P_S1
# {'long_name': 'mineral P flux for decomp. of SOIL1to SOIL2', 'units': 'gP/m^2', 'cell_methods': 'time: mean'}
# SMINP_TO_SOIL3P_L3
# {'long_name': 'mineral P flux for decomp. of LITR3to SOIL3', 'units': 'gP/m^2', 'cell_methods': 'time: mean'}
# SMINP_TO_SOIL3P_S2
# {'long_name': 'mineral P flux for decomp. of SOIL2to SOIL3', 'units': 'gP/m^2', 'cell_methods': 'time: mean'}
# SMINP_TO_SOIL4P_S3
# {'long_name': 'mineral P flux for decomp. of SOIL3to SOIL4', 'units': 'gP/m^2', 'cell_methods': 'time: mean'}
# SMINP_vr
# {'long_name': 'soil mineral P (vert. res.)', 'units': 'gp/m^3', 'cell_methods': 'time: mean'}
# SMIN_NH4
# {'long_name': 'soil mineral NH4', 'units': 'gN/m^2', 'cell_methods': 'time: mean'}
# SMIN_NH4_vr
# {'long_name': 'soil mineral NH4 (vert. res.)', 'units': 'gN/m^3', 'cell_methods': 'time: mean'}
# SMIN_NO3
# {'long_name': 'soil mineral NO3', 'units': 'gN/m^2', 'cell_methods': 'time: mean'}
# SMIN_NO3_LEACHED
# {'long_name': 'soil NO3 pool loss to leaching', 'units': 'gN/m^2/s', 'cell_methods': 'time: mean'}
# SMIN_NO3_RUNOFF
# {'long_name': 'soil NO3 pool loss to runoff', 'units': 'gN/m^2/s', 'cell_methods': 'time: mean'}
# SMIN_NO3_vr
# {'long_name': 'soil mineral NO3 (vert. res.)', 'units': 'gN/m^3', 'cell_methods': 'time: mean'}
# SNOBCMCL
# {'long_name': 'mass of BC in snow column', 'units': 'kg/m2', 'cell_methods': 'time: mean'}
# SNOBCMSL
# {'long_name': 'mass of BC in top snow layer', 'units': 'kg/m2', 'cell_methods': 'time: mean'}
# SNODSTMCL
# {'long_name': 'mass of dust in snow column', 'units': 'kg/m2', 'cell_methods': 'time: mean'}
# SNODSTMSL
# {'long_name': 'mass of dust in top snow layer', 'units': 'kg/m2', 'cell_methods': 'time: mean'}
# SNOINTABS
# {'long_name': 'Percent of incoming solar absorbed by lower snow layers', 'units': '%', 'cell_methods': 'time: mean'}
# SNOOCMCL
# {'long_name': 'mass of OC in snow column', 'units': 'kg/m2', 'cell_methods': 'time: mean'}
# SNOOCMSL
# {'long_name': 'mass of OC in top snow layer', 'units': 'kg/m2', 'cell_methods': 'time: mean'}
# SNOW
# {'long_name': 'atmospheric snow', 'units': 'mm/s', 'cell_methods': 'time: mean'}
# SNOWDP
# {'long_name': 'gridcell mean snow height', 'units': 'm', 'cell_methods': 'time: mean'}
# SNOWICE
# {'long_name': 'snow ice', 'units': 'kg/m2', 'cell_methods': 'time: mean'}
# SNOWLIQ
# {'long_name': 'snow liquid water', 'units': 'kg/m2', 'cell_methods': 'time: mean'}
# SNOW_DEPTH
# {'long_name': 'snow height of snow covered area', 'units': 'm', 'cell_methods': 'time: mean'}
# SNOW_SINKS
# {'long_name': 'snow sinks (liquid water)', 'units': 'mm/s', 'cell_methods': 'time: mean'}
# SNOW_SOURCES
# {'long_name': 'snow sources (liquid water)', 'units': 'mm/s', 'cell_methods': 'time: mean'}
# SOIL1C
# {'long_name': 'SOIL1 C', 'units': 'gC/m^2', 'cell_methods': 'time: mean'}
# SOIL1C_vr
# {'long_name': 'SOIL1 C (vertically resolved)', 'units': 'gC/m^3', 'cell_methods': 'time: mean'}
# SOIL1N
# {'long_name': 'SOIL1 N', 'units': 'gN/m^2', 'cell_methods': 'time: mean'}
# SOIL1N_TNDNCY_VERT_TRANS
# {'long_name': 'soil 1 N tendency due to vertical transport', 'units': 'gN/m^3/s', 'cell_methods': 'time: mean'}
# SOIL1N_TO_SOIL2N
# {'long_name': 'decomp. of soil 1 N to soil 2 N', 'units': 'gN/m^2', 'cell_methods': 'time: mean'}
# SOIL1N_vr
# {'long_name': 'SOIL1 N (vertically resolved)', 'units': 'gN/m^3', 'cell_methods': 'time: mean'}
# SOIL1P
# {'long_name': 'SOIL1 P', 'units': 'gP/m^2', 'cell_methods': 'time: mean'}
# SOIL1P_TNDNCY_VERT_TRANS
# {'long_name': 'soil 1 P tendency due to vertical transport', 'units': 'gP/m^3/s', 'cell_methods': 'time: mean'}
# SOIL1P_TO_SOIL2P
# {'long_name': 'decomp. of soil 1 P to soil 2 N', 'units': 'gP/m^2', 'cell_methods': 'time: mean'}
# SOIL1P_vr
# {'long_name': 'SOIL1 P (vertically resolved)', 'units': 'gP/m^3', 'cell_methods': 'time: mean'}
# SOIL2C
# {'long_name': 'SOIL2 C', 'units': 'gC/m^2', 'cell_methods': 'time: mean'}
# SOIL2C_vr
# {'long_name': 'SOIL2 C (vertically resolved)', 'units': 'gC/m^3', 'cell_methods': 'time: mean'}
# SOIL2N
# {'long_name': 'SOIL2 N', 'units': 'gN/m^2', 'cell_methods': 'time: mean'}
# SOIL2N_TNDNCY_VERT_TRANS
# {'long_name': 'soil 2 N tendency due to vertical transport', 'units': 'gN/m^3/s', 'cell_methods': 'time: mean'}
# SOIL2N_TO_SOIL3N
# {'long_name': 'decomp. of soil 2 N to soil 3 N', 'units': 'gN/m^2', 'cell_methods': 'time: mean'}
# SOIL2N_vr
# {'long_name': 'SOIL2 N (vertically resolved)', 'units': 'gN/m^3', 'cell_methods': 'time: mean'}
# SOIL2P
# {'long_name': 'SOIL2 P', 'units': 'gP/m^2', 'cell_methods': 'time: mean'}
# SOIL2P_TNDNCY_VERT_TRANS
# {'long_name': 'soil 2 P tendency due to vertical transport', 'units': 'gP/m^3/s', 'cell_methods': 'time: mean'}
# SOIL2P_TO_SOIL3P
# {'long_name': 'decomp. of soil 2 P to soil 3 N', 'units': 'gP/m^2', 'cell_methods': 'time: mean'}
# SOIL2P_vr
# {'long_name': 'SOIL2 P (vertically resolved)', 'units': 'gP/m^3', 'cell_methods': 'time: mean'}
# SOIL3C
# {'long_name': 'SOIL3 C', 'units': 'gC/m^2', 'cell_methods': 'time: mean'}
# SOIL3C_vr
# {'long_name': 'SOIL3 C (vertically resolved)', 'units': 'gC/m^3', 'cell_methods': 'time: mean'}
# SOIL3N
# {'long_name': 'SOIL3 N', 'units': 'gN/m^2', 'cell_methods': 'time: mean'}
# SOIL3N_TNDNCY_VERT_TRANS
# {'long_name': 'soil 3 N tendency due to vertical transport', 'units': 'gN/m^3/s', 'cell_methods': 'time: mean'}
# SOIL3N_TO_SOIL4N
# {'long_name': 'decomp. of soil 3 N to soil 4 N', 'units': 'gN/m^2', 'cell_methods': 'time: mean'}
# SOIL3N_vr
# {'long_name': 'SOIL3 N (vertically resolved)', 'units': 'gN/m^3', 'cell_methods': 'time: mean'}
# SOIL3P
# {'long_name': 'SOIL3 P', 'units': 'gP/m^2', 'cell_methods': 'time: mean'}
# SOIL3P_TNDNCY_VERT_TRANS
# {'long_name': 'soil 3 P tendency due to vertical transport', 'units': 'gP/m^3/s', 'cell_methods': 'time: mean'}
# SOIL3P_TO_SOIL4P
# {'long_name': 'decomp. of soil 3 P to soil 4 N', 'units': 'gP/m^2', 'cell_methods': 'time: mean'}
# SOIL3P_vr
# {'long_name': 'SOIL3 P (vertically resolved)', 'units': 'gP/m^3', 'cell_methods': 'time: mean'}
# SOIL4C
# {'long_name': 'SOIL4 C', 'units': 'gC/m^2', 'cell_methods': 'time: mean'}
# SOIL4C_vr
# {'long_name': 'SOIL4 C (vertically resolved)', 'units': 'gC/m^3', 'cell_methods': 'time: mean'}
# SOIL4N
# {'long_name': 'SOIL4 N', 'units': 'gN/m^2', 'cell_methods': 'time: mean'}
# SOIL4N_TNDNCY_VERT_TRANS
# {'long_name': 'soil 4 N tendency due to vertical transport', 'units': 'gN/m^3/s', 'cell_methods': 'time: mean'}
# SOIL4N_TO_SMINN
# {'long_name': 'mineral N flux for decomp. of SOIL4', 'units': 'gN/m^2', 'cell_methods': 'time: mean'}
# SOIL4N_vr
# {'long_name': 'SOIL4 N (vertically resolved)', 'units': 'gN/m^3', 'cell_methods': 'time: mean'}
# SOIL4P
# {'long_name': 'SOIL4 P', 'units': 'gP/m^2', 'cell_methods': 'time: mean'}
# SOIL4P_TNDNCY_VERT_TRANS
# {'long_name': 'soil 4 P tendency due to vertical transport', 'units': 'gP/m^3/s', 'cell_methods': 'time: mean'}
# SOIL4P_TO_SMINP
# {'long_name': 'mineral P flux for decomp. of SOIL4', 'units': 'gP/m^2', 'cell_methods': 'time: mean'}
# SOIL4P_vr
# {'long_name': 'SOIL4 P (vertically resolved)', 'units': 'gP/m^3', 'cell_methods': 'time: mean'}
# SOILC
# {'long_name': 'soil C', 'units': 'gC/m^2', 'cell_methods': 'time: mean'}
# SOILICE
# {'long_name': 'soil ice (vegetated landunits only)', 'units': 'kg/m2', 'cell_methods': 'time: mean'}
# SOILICE_ICE
# {'long_name': 'soil ice (ice landunits only)', 'units': 'kg/m2', 'cell_methods': 'time: mean'}
# SOILLIQ
# {'long_name': 'soil liquid water (vegetated landunits only)', 'units': 'kg/m2', 'cell_methods': 'time: mean'}
# SOILLIQ_ICE
# {'long_name': 'soil liquid water (ice landunits only)', 'units': 'kg/m2', 'cell_methods': 'time: mean'}
# SOILPSI
# {'long_name': 'soil water potential in each soil layer', 'units': 'MPa', 'cell_methods': 'time: mean'}
# SOILWATER_10CM
# {'long_name': 'soil liquid water + ice in top 10cm of soil (veg landunits only)', 'standard_name': 'mass_content_of_water_in_soil_layer', 'units': 'kg/m2', 'cell_methods': 'time: mean'}
# SOLUTIONP
# {'long_name': 'soil solution P', 'units': 'gP/m^2', 'cell_methods': 'time: mean'}
# SOLUTIONP_vr
# {'long_name': 'soil solution P (vert. res.)', 'units': 'gp/m^3', 'cell_methods': 'time: mean'}
# SOMHR
# {'long_name': 'soil organic matter heterotrophic respiration', 'units': 'gC/m^2/s', 'cell_methods': 'time: mean'}
# SOM_C_LEACHED
# {'long_name': 'total flux of C from SOM pools due to leaching', 'units': 'gC/m^2/s', 'cell_methods': 'time: mean'}
# STOREC
# {'long_name': 'Total carbon in live plant storage', 'units': 'kgC ha-1', 'cell_methods': 'time: mean'}
# SUM_FUEL
# {'long_name': 'total ground fuel related to ros (omits 1000hr fuels)', 'units': 'gC m-2', 'cell_methods': 'time: mean'}
# SUM_FUEL_BY_PATCH_AGE
# {'long_name': 'spitfire ground fuel related to ros (omits 1000hr fuels) within each patch age bin (divide by patch_area_by_age to get fuel per', 'units': 'gC / m2 of site area', 'cell_methods': 'time: mean'}
# SUPPLEMENT_TO_SMINN
# {'long_name': 'supplemental N supply', 'units': 'gN/m^2/s', 'cell_methods': 'time: mean'}
# SUPPLEMENT_TO_SMINP
# {'long_name': 'supplemental P supply', 'units': 'gP/m^2/s', 'cell_methods': 'time: mean'}
# SUPPLY
# {'long_name': 'runoff supply for land use', 'units': 'mm/s', 'cell_methods': 'time: mean'}
# SoilAlpha
# {'long_name': 'factor limiting ground evap', 'units': '1', 'cell_methods': 'time: mean'}
# SoilAlpha_U
# {'long_name': 'urban factor limiting ground evap', 'units': '1', 'cell_methods': 'time: mean'}
# TAUX
# {'long_name': 'zonal surface stress', 'units': 'kg/m/s^2', 'cell_methods': 'time: mean'}
# TAUY
# {'long_name': 'meridional surface stress', 'units': 'kg/m/s^2', 'cell_methods': 'time: mean'}
# TBOT
# {'long_name': 'atmospheric air temperature', 'units': 'K', 'cell_methods': 'time: mean'}
# TBUILD
# {'long_name': 'internal urban building temperature', 'units': 'K', 'cell_methods': 'time: mean'}
# TCS_MONTH_BEGIN
# {'long_name': 'total carbon storage at the beginning of a month', 'units': 'mm', 'cell_methods': 'time: point'}
# TCS_MONTH_END
# {'long_name': 'total carbon storage at the end of a month', 'units': 'mm', 'cell_methods': 'time: point'}
# TG
# {'long_name': 'ground temperature', 'units': 'K', 'cell_methods': 'time: mean'}
# TG_R
# {'long_name': 'Rural ground temperature', 'units': 'K', 'cell_methods': 'time: mean'}
# TG_U
# {'long_name': 'Urban ground temperature', 'units': 'K', 'cell_methods': 'time: mean'}
# TH2OSFC
# {'long_name': 'surface water temperature', 'units': 'K', 'cell_methods': 'time: mean'}
# THBOT
# {'long_name': 'atmospheric air potential temperature', 'units': 'K', 'cell_methods': 'time: mean'}
# TKE1
# {'long_name': 'top lake level eddy thermal conductivity', 'units': 'W/(mK)', 'cell_methods': 'time: mean'}
# TLAI
# {'long_name': 'total projected leaf area index', 'units': '1', 'cell_methods': 'time: mean'}
# TLAKE
# {'long_name': 'lake temperature', 'units': 'K', 'cell_methods': 'time: mean'}
# TOTCOLC
# {'long_name': 'total column carbon, incl veg and cpool but excl product pools', 'units': 'gC/m^2', 'cell_methods': 'time: mean'}
# TOTCOLN
# {'long_name': 'total column-level N but excl product pools', 'units': 'gN/m^2', 'cell_methods': 'time: mean'}
# TOTCOLP
# {'long_name': 'total column-level P but excl product pools', 'units': 'gP/m^2', 'cell_methods': 'time: mean'}
# TOTECOSYSC
# {'long_name': 'total ecosystem carbon, incl veg but excl cpool but excl product pools', 'units': 'gC/m^2', 'cell_methods': 'time: mean'}
# TOTECOSYSN
# {'long_name': 'total ecosystem N but excl product pools', 'units': 'gN/m^2', 'cell_methods': 'time: mean'}
# TOTECOSYSP
# {'long_name': 'total ecosystem P but excl product pools', 'units': 'gP/m^2', 'cell_methods': 'time: mean'}
# TOTLITC
# {'long_name': 'total litter carbon', 'units': 'gC/m^2', 'cell_methods': 'time: mean'}
# TOTLITC_1m
# {'long_name': 'total litter carbon to 1 meter depth', 'units': 'gC/m^2', 'cell_methods': 'time: mean'}
# TOTLITN
# {'long_name': 'total litter N', 'units': 'gN/m^2', 'cell_methods': 'time: mean'}
# TOTLITP
# {'long_name': 'total litter P', 'units': 'gP/m^2', 'cell_methods': 'time: mean'}
# TOTLITP_1m
# {'long_name': 'total litter P to 1 meter', 'units': 'gP/m^2', 'cell_methods': 'time: mean'}
# TOTSOMC
# {'long_name': 'total soil organic matter carbon', 'units': 'gC/m^2', 'cell_methods': 'time: mean'}
# TOTSOMC_1m
# {'long_name': 'total soil organic matter carbon to 1 meter depth', 'units': 'gC/m^2', 'cell_methods': 'time: mean'}
# TOTSOMN
# {'long_name': 'total soil organic matter N', 'units': 'gN/m^2', 'cell_methods': 'time: mean'}
# TOTSOMP
# {'long_name': 'total soil organic matter P', 'units': 'gP/m^2', 'cell_methods': 'time: mean'}
# TOTSOMP_1m
# {'long_name': 'total soil organic matter P to 1 meter', 'units': 'gP/m^2', 'cell_methods': 'time: mean'}
# TOTVEGC
# {'long_name': 'Total carbon in live plants', 'units': 'kgC ha-1', 'cell_methods': 'time: mean'}
# TREFMNAV
# {'long_name': 'daily minimum of average 2-m temperature', 'units': 'K', 'cell_methods': 'time: mean'}
# TREFMNAV_R
# {'long_name': 'Rural daily minimum of average 2-m temperature', 'units': 'K', 'cell_methods': 'time: mean'}
# TREFMNAV_U
# {'long_name': 'Urban daily minimum of average 2-m temperature', 'units': 'K', 'cell_methods': 'time: mean'}
# TREFMXAV
# {'long_name': 'daily maximum of average 2-m temperature', 'units': 'K', 'cell_methods': 'time: mean'}
# TREFMXAV_R
# {'long_name': 'Rural daily maximum of average 2-m temperature', 'units': 'K', 'cell_methods': 'time: mean'}
# TREFMXAV_U
# {'long_name': 'Urban daily maximum of average 2-m temperature', 'units': 'K', 'cell_methods': 'time: mean'}
# TRIMMING
# {'long_name': 'Degree to which canopy expansion is limited by leaf economics', 'units': 'none', 'cell_methods': 'time: mean'}
# TSA
# {'long_name': '2m air temperature', 'units': 'K', 'cell_methods': 'time: mean'}
# TSAI
# {'long_name': 'total projected stem area index', 'units': '1', 'cell_methods': 'time: mean'}
# TSA_R
# {'long_name': 'Rural 2m air temperature', 'units': 'K', 'cell_methods': 'time: mean'}
# TSA_U
# {'long_name': 'Urban 2m air temperature', 'units': 'K', 'cell_methods': 'time: mean'}
# TSOI
# {'long_name': 'soil temperature (vegetated landunits only)', 'standard_name': 'soil_temperature', 'units': 'K', 'cell_methods': 'time: mean'}
# TSOI_10CM
# {'long_name': 'soil temperature in top 10cm of soil', 'units': 'K', 'cell_methods': 'time: mean'}
# TSOI_ICE
# {'long_name': 'soil temperature (ice landunits only)', 'units': 'K', 'cell_methods': 'time: mean'}
# TV
# {'long_name': 'vegetation temperature', 'units': 'K', 'cell_methods': 'time: mean'}
# TWS
# {'long_name': 'total water storage', 'units': 'mm', 'cell_methods': 'time: mean'}
# TWS_MONTH_BEGIN
# {'long_name': 'total water storage at the beginning of a month', 'units': 'mm', 'cell_methods': 'time: point'}
# TWS_MONTH_END
# {'long_name': 'total water storage at the end of a month', 'units': 'mm', 'cell_methods': 'time: point'}
# U10
# {'long_name': '10-m wind', 'units': 'm/s', 'cell_methods': 'time: mean'}
# URBAN_AC
# {'long_name': 'urban air conditioning flux', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# URBAN_HEAT
# {'long_name': 'urban heating flux', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# VOLR
# {'long_name': 'river channel total water storage', 'units': 'm3', 'cell_methods': 'time: mean'}
# VOLRMCH
# {'long_name': 'river channel main channel water storage', 'units': 'm3', 'cell_methods': 'time: mean'}
# WA
# {'long_name': 'water in the unconfined aquifer (vegetated landunits only)', 'units': 'mm', 'cell_methods': 'time: mean'}
# WASTEHEAT
# {'long_name': 'sensible heat flux from heating/cooling sources of urban waste heat', 'units': 'W/m^2', 'cell_methods': 'time: mean'}
# WIND
# {'long_name': 'atmospheric wind velocity magnitude', 'units': 'm/s', 'cell_methods': 'time: mean'}
# ZBOT
# {'long_name': 'atmospheric reference height', 'units': 'm', 'cell_methods': 'time: mean'}
# ZSTAR_BY_AGE
# {'long_name': 'product of zstar and patch area by age bin (divide by PATCH_AREA_BY_AGE to get mean zstar)', 'units': 'm', 'cell_methods': 'time: mean'}
# ZWT
# {'long_name': 'water table depth (vegetated landunits only)', 'units': 'm', 'cell_methods': 'time: mean'}
# ZWT_PERCH
# {'long_name': 'perched water table depth (vegetated landunits only)', 'units': 'm', 'cell_methods': 'time: mean'}

# %%
Fuel_Amount=ProcessbyFuelClass(Fates_xr,'FUEL_AMOUNT_BY_NFSC',Time)
def plotterfuel(data,titlelabel,xlabel,ylabel):
    data['Total']=data['FuelClass1']+data['FuelClass2']+data['FuelClass3']+data['FuelClass5']+data['FuelClass6']
    fig, ax = plt.subplots(figsize=(12, 10))
    plt.title(titlelabel, fontsize=20)
    plt.plot(data['FuelClass1'],label="twigs")
    plt.plot(data['FuelClass2'],label="small stems")
    plt.plot(data['FuelClass3'],label="large stems")
    plt.plot(data['FuelClass4'],label="Trunks")   
    plt.plot(data['FuelClass5'],label="deadleaves")
    plt.plot(data['FuelClass6'],label="livegrass") 
    #plt.plot(data['Total'],label='Total')
    ax.set_xlabel(xlabel, labelpad=15, fontsize=20, color="#333533");
    ax.set_ylabel(ylabel, labelpad=15, fontsize=20, color="#333533");
    plt.legend(bbox_to_anchor=(1.04,1), loc="upper left",prop={'size': 20})
    
plotterfuel(Fuel_Amount,'Fuelsmass','time','g/m')   
Fuel_Amount.to_csv("CombinedFuelBreakdown.csv")

max(Fuel_Amount['FuelClass1'])
max(Fuel_Amount['FuelClass2'])
max(Fuel_Amount['FuelClass3'])
max(Fuel_Amount['FuelClass4'])
max(Fuel_Amount['FuelClass5'])
max(Fuel_Amount['FuelClass6'])
# Out:
# 0.012039144523441792
# 0.022518353536725044
# 0.06305138766765594
# 0.2398044466972351
# 0.49890825152397156
# 0.046728186309337616

# %%
Fuel_Amount=ProcessbyFuelClass(Fates_xr,'FUEL_MOISTURE_NFSC',Time)
plotterfuel(Fuel_Amount,'Fuelsmoisture','time','%')

# %%
var=np.array(Fates_xr['area'])
print(var)
#fig, ax = plt.subplots(figsize=(9, 7))
#plt.title( 'NI', fontsize=16)
#plt.axhline(y=1.58, color='r', linestyle='-')
#plt.axhline(y=8.17, color='r', linestyle='-')
#plt.plot(Time,var)
#2054*.092903
# Out:
# [40592444.]

# %%
var=np.array(Fates_xr['AGB'])
var=pd.DataFrame({'NI':var.flatten()},index=Time).groupby(pd.Grouper(freq="y")).sum()
fig, ax = plt.subplots(figsize=(9, 7))
plt.title("Fire ignitions per year", fontsize=16)
#plt.axhline(y=1.58, color='r', linestyle='-')
#plt.axhline(y=8.17, color='r', linestyle='-')
plt.plot(var.NI)
# Out:
# Text(0.5, 1.0, 'Fire ignitions per year')

# %%
var=np.array(Fates_xr['SUM_FUEL'])
fig, ax = plt.subplots(figsize=(9, 7))
plt.title("Fire intensity (kJ/m/s)", fontsize=16)
#plt.axhline(y=1.58, color='r', linestyle='-')
#plt.axhline(y=8.17, color='r', linestyle='-')
plt.plot(Time,var)
# Out:
# Text(0.5, 1.0, 'Fire intensity (kJ/m/s)')

# %%
var=np.array(Fates_xr['FIRE_FUEL_BULKD'])
fig, ax = plt.subplots(figsize=(9, 7))
plt.title("Fuel Bulkdensity kg biomass/m3", fontsize=16)
plt.axhline(y=1.58, color='r', linestyle='-')
plt.axhline(y=8.17, color='r', linestyle='-')
plt.plot(Time,var)
# Out:
# Text(0.5, 1.0, 'Fuel Bulkdensity kg biomass/m3')

# %%
var=np.array(Fates_xr['FIRE_NESTEROV_INDEX'])
var=pd.DataFrame({'NI':var.flatten()},index=Time).groupby(pd.Grouper(freq="y")).mean()
fig, ax = plt.subplots(figsize=(9, 7))
plt.title("Nesterov index", fontsize=16)
plt.plot(var.NI)
# Out:
# Text(0.5, 1.0, 'Nesterov index')

# %%
var=np.array(Fates_xr['FIRE_INTENSITY'])

var=pd.DataFrame({'Ignitions':var.flatten()},index=Time).groupby(pd.Grouper(freq="y")).sum()
fig, ax = plt.subplots(figsize=(9, 7))
plt.title(" (kJ/m/s)", fontsize=16)
plt.plot(var.Ignitions)
# Out:
# Text(0.5, 1.0, ' (kJ/m/s)')

# %%
var=np.array(Fates_xr['FIRE_FUEL_SAV'])
fig, ax = plt.subplots(figsize=(9, 7))
plt.title('Moisture of Exitinction', fontsize=16)
plt.plot(Time,var)
# Out:
# Text(0.5, 1.0, 'Moisture of Exitinction')

# %%
var=np.array(Fates_xr['FIRE_INTENSITY'])
fig, ax = plt.subplots(figsize=(9, 7))
plt.title('Intensity', fontsize=16)
plt.plot(Time,var)
# Out:
# Text(0.5, 1.0, 'Intensity')

# %%
var=np.array(Fates_xr['AGB'])
fig, ax = plt.subplots(figsize=(9, 7))
plt.title('Aboveground biomass', fontsize=16)
plt.plot(Time,var)
# Out:
# Text(0.5, 1.0, 'Aboveground biomass')

# %%
checkout=ProcessbyPAge(Fates_xr,'AREA_BURNT_BY_PATCH_AGE',Time)
plotterage(checkout,"Area burnt","Year","Area Burnt",'lower right')

# %%
LeafBiobyPFt=ProcesbyPFT(Fates_xr,'PFTleafbiomass',Time,["chaparral","grass"])
plotterpft(LeafBiobyPFt,["chaparral","grass"],"LeafBiomass","Time","Biomass")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-31-4cf2934d1821> in <module>
# ----> 1 LeafBiobyPFt=ProcesbyPFT(Fates_xr,'PFTleafbiomass',Time,["chaparral","grass"])
#       2 plotterpft(LeafBiobyPFt,["chaparral","grass"],"LeafBiomass","Time","Biomass")
#
# <ipython-input-16-776f4be2093b> in ProcesbyPFT(Data, Var, Time, PFT)
#      26 def ProcesbyPFT(Data,Var,Time,PFT):
#      27     out=pd.DataFrame({PFT[0]:np.array(Data[Var][:,0]).flatten(),
# ---> 28               PFT[1]:np.array(Data[Var][:,1]).flatten(),
#      29               },index=Time)
#      30     return(out)
#
# ~\Anaconda3\envs\NCDF\lib\site-packages\xarray\core\dataarray.py in __getitem__(self, key)
#     704         else:
#     705             # xarray-style array indexing
# --> 706             return self.isel(indexers=self._item_key_to_dict(key))
#     707
#     708     def __setitem__(self, key: Any, value: Any) -> None:
#
# ~\Anaconda3\envs\NCDF\lib\site-packages\xarray\core\dataarray.py in isel(self, indexers, drop, missing_dims, **indexers_kwargs)
#    1145         # lists, or zero or one-dimensional np.ndarray's
#    1146
# -> 1147         variable = self._variable.isel(indexers, missing_dims=missing_dims)
#    1148
#    1149         coords = {}
#
# ~\Anaconda3\envs\NCDF\lib\site-packages\xarray\core\variable.py in isel(self, indexers, missing_dims, **indexers_kwargs)
#    1133
#    1134         key = tuple(indexers.get(dim, slice(None)) for dim in self.dims)
# -> 1135         return self[key]
#    1136
#    1137     def squeeze(self, dim=None):
#
# ~\Anaconda3\envs\NCDF\lib\site-packages\xarray\core\variable.py in __getitem__(self, key)
#     778         """
#     779         dims, indexer, new_order = self._broadcast_indexes(key)
# --> 780         data = as_indexable(self._data)[indexer]
#     781         if new_order:
#     782             data = duck_array_ops.moveaxis(data, range(len(new_order)), new_order)
#
# ~\Anaconda3\envs\NCDF\lib\site-packages\xarray\core\indexing.py in __getitem__(self, key)
#     703
#     704     def __getitem__(self, key):
# --> 705         return type(self)(_wrap_numpy_scalars(self.array[key]))
#     706
#     707     def transpose(self, order):
#
# ~\Anaconda3\envs\NCDF\lib\site-packages\xarray\core\indexing.py in __getitem__(self, key)
#     672
#     673     def __getitem__(self, key):
# --> 674         return type(self)(_wrap_numpy_scalars(self.array[key]))
#     675
#     676     def transpose(self, order):
#
# ~\Anaconda3\envs\NCDF\lib\site-packages\xarray\core\indexing.py in __getitem__(self, indexer)
#     579             array = LazilyVectorizedIndexedArray(self.array, self.key)
#     580             return array[indexer]
# --> 581         return type(self)(self.array, self._updated_key(indexer))
#     582
#     583     def __setitem__(self, key, value):
#
# ~\Anaconda3\envs\NCDF\lib\site-packages\xarray\core\indexing.py in _updated_key(self, new_key)
#     551                 full_key.append(k)
#     552             else:
# --> 553                 full_key.append(_index_indexer_1d(k, next(iter_new_key), size))
#     554         full_key = tuple(full_key)
#     555
#
# ~\Anaconda3\envs\NCDF\lib\site-packages\xarray\core\indexing.py in _index_indexer_1d(old_indexer, applied_indexer, size)
#     324             indexer = slice_slice(old_indexer, applied_indexer, size)
#     325         else:
# --> 326             indexer = _expand_slice(old_indexer, size)[applied_indexer]
#     327     else:
#     328         indexer = old_indexer[applied_indexer]
#
# IndexError: index 1 is out of bounds for axis 0 with size 1
